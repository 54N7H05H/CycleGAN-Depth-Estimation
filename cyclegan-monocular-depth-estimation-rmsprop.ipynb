# %%
import torch
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt


from PIL import Image
from torchvision.transforms import transforms
from torch.utils.data import DataLoader, Dataset
from torch.autograd import Variable

import os
import cv2
import numpy as np
import random
import glob

import warnings
warnings.filterwarnings("ignore")

# %%
def real_mse_loss(D_out):
    return torch.mean((D_out-1)**2)

def fake_mse_loss(D_out):
    return torch.mean(D_out**2)

def cycle_consistency_loss(real_im, reconstructed_im, lambda_weight):
    reconstr_loss = torch.mean(torch.abs(real_im - reconstructed_im))
    return lambda_weight*reconstr_loss

class LambdaLR:
    def __init__(self, n_epochs, decay_start_epoch):
        assert ((n_epochs - decay_start_epoch) > 0), "Decay must start before the training session ends!"
        self.n_epochs = n_epochs
        self.decay_start_epoch = decay_start_epoch

    def step(self, epoch):
        return 1.0 - max(0, epoch - self.decay_start_epoch)/(self.n_epochs - self.decay_start_epoch)

def weights_init_normal(m):
    classname = m.__class__.__name__

    if classname.find('Conv') != -1:
        torch.nn.init.normal(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm2d') != -1:
        torch.nn.init.normal(m.weight.data, 1.0, 0.02)
        torch.nn.init.constant(m.bias.data, 0.0)

def scale(x, feature_range=(-1, 1)):
    min, max = feature_range
    x = x * (max - min) + min
    return x

def to_data(x):
    if torch.cuda.is_available():
        x = x.cpu()
    x = x.data.numpy()
    x = ((x +1)*255 / (2)).astype(np.uint8) # rescale to 0-255
    return x

def checkpoint(iteration, G_A2B, G_B2A, D_A, D_B, checkpoint_dir='checkpoints'):
    os.makedirs(checkpoint_dir, exist_ok=True)
    G_A2B_path = os.path.join(checkpoint_dir, 'gen_A2B.pkl')
    G_B2A_path = os.path.join(checkpoint_dir, 'gen_B2A.pkl')
    D_A_path = os.path.join(checkpoint_dir, 'disc_A.pkl')
    D_B_path = os.path.join(checkpoint_dir, 'disc_B.pkl')
    torch.save(G_A2B.state_dict(), G_A2B_path)
    torch.save(G_B2A.state_dict(), G_B2A_path)
    torch.save(D_A.state_dict(), D_A_path)
    torch.save(D_B.state_dict(), D_B_path)

# %%
DATASET_DIRECTORY = '/kaggle/input/monocular-depth-estimation/val/indoors'

dataset = {}
for subdir, dirs, files in os.walk(DATASET_DIRECTORY):
  for file in files:
    basename = os.path.basename(os.path.join(subdir, file))
    if basename[-3:] == "png":
      basename = basename[:-4]
      kind = "rgb"
    elif basename[-9:] == "depth.npy":
      basename = basename[:-10]
      kind = "depth"
    elif basename[-14:] == "depth_mask.npy":
      basename = basename[:-15]
      kind = "mask"
    else:
      continue

    if not basename in dataset:
      dataset[basename] = { "rgb": None, "depth": None, "mask": None }
    dataset[basename][kind] = os.path.join(subdir, file)

# %%
class DIODEDataset(Dataset):
    def __init__(self, img_size=256, batch_size = 16, num_workers=0):
        super(Dataset, self).__init__()
        self.batch_size = batch_size
        self.img_size = img_size
        self.num_workers = num_workers
        self.keys = list(dataset.keys())
        
    def __len__(self):
        return len(dataset)
    
    @staticmethod
    def normalize(img):
        return (img * 2) - 1
    
    @staticmethod
    def denormalize(img):
        return (img + 1) / 2

    def __getitem__(self, idx):
        name = self.keys[idx]
        
        rgb = Image.open(dataset[name]['rgb'])
        rgb = np.array(rgb)
        rgb = ((rgb - np.min(rgb)) / (np.max(rgb) - np.min(rgb)))
        rgb = rgb.astype(np.float32)
        
        depth = dataset[name]["depth"]
        depth = np.load(depth).squeeze()

        mask = dataset[name]["mask"]
        mask = np.load(mask)
        mask = mask > 0

        max_depth = min(300, np.percentile(depth, 99))
        depth = np.clip(depth, 0.1, max_depth)
        depth = np.log(depth, where=mask)
        depth = np.ma.masked_where(~mask, depth)
        depth = np.clip(depth, 0.1, np.log(max_depth))
        depth = np.expand_dims(depth, axis=2)
        depth = np.concatenate([depth] * 3, axis=2)
        depth = ((depth - np.min(depth)) / (np.max(depth) - np.min(depth)))
        depth = depth.astype(np.float32)
        
        rgb, depth = torch.from_numpy(rgb), torch.from_numpy(depth)
        rgb, depth = rgb.permute(2, 0, 1), depth.permute(2, 0, 1)
        rgb = transforms.Resize((256, 256))(rgb)
        depth = transforms.Resize((256, 256))(depth)
        
        return rgb, depth

# %%
class ResnetBlock(nn.Module):
    def __init__(self,input_features):
        super(ResnetBlock, self).__init__()
        Resnet_convolution = [
                              nn.ReflectionPad2d(1),
                              nn.Conv2d(input_features,input_features,3),
                              nn.InstanceNorm2d(input_features),
                              nn.LeakyReLU(negative_slope = 0.01),
                              nn.ReflectionPad2d(1),
                              nn.Conv2d(input_features, input_features,3),
                              nn.InstanceNorm2d(input_features)
                             ]
        self.Resnet_convolution = nn.Sequential(*Resnet_convolution)

    def forward(self, x):
        return x+self.Resnet_convolution(x)

# %%
class Generator(nn.Module):
    def __init__(self, input_channels, num_ResnetBlocks = 6):

        super(Generator,self).__init__()

        GeneratorArchitecture = [
            nn.ReflectionPad2d(3),
            nn.Conv2d(input_channels,64,7),
            nn.InstanceNorm2d(64),
            nn.LeakyReLU(negative_slope = 0.01, inplace = True)
        ]

        input_features = 64
        output_features = input_features*2

        for _ in range(2):
            GeneratorArchitecture += [
                nn.Conv2d(input_features, output_features,3,stride =2, padding =1),
                nn.InstanceNorm2d(output_features),
                nn.PReLU(init =0.25)
            ]

            input_features = output_features
            output_features = input_features*2

        for _ in range(num_ResnetBlocks):
            GeneratorArchitecture += [ ResnetBlock(input_features) ]

        output_features = input_features//2

        for _ in range(2):
            GeneratorArchitecture += [
                nn.ConvTranspose2d(input_features, output_features,3, stride =2, padding=1, output_padding =1),
                nn.InstanceNorm2d(output_features),
                nn.PReLU(init =0.25)
            ]
            input_features= output_features
            output_features = input_features//2


        GeneratorArchitecture += [
            nn.ReflectionPad2d(3),
            nn.Conv2d(input_features, input_channels,7),
            nn.Tanh()
        ]

        self.GeneratorArchitecture = nn.Sequential(*GeneratorArchitecture)

    def forward(self, x):
        return self.GeneratorArchitecture(x)

# %%
# @title
class Discriminator(nn.Module):

    def __init__(self, input_channels):
        super(Discriminator,self).__init__()

        DiscriminatorArchitecture = [
            nn.Conv2d(input_channels, 128, 4, stride =2, padding=1),
            nn.LeakyReLU(negative_slope = 0.01, inplace = True),
        ]
        DiscriminatorArchitecture += [
            nn.Conv2d(128, 256,4,stride=2, padding =1),
            nn.InstanceNorm2d (256),
            nn.LeakyReLU(negative_slope = 0.01, inplace = True)
        ]
        DiscriminatorArchitecture += [
            nn.Conv2d(256,512,3, padding =1),
            nn.InstanceNorm2d (256),
            nn.LeakyReLU(negative_slope = 0.01, inplace = True)
        ]
        DiscriminatorArchitecture += [  nn.Conv2d(512, 1, 4, padding =1) ]

        self.DiscriminatorArchitecture = nn.Sequential(*DiscriminatorArchitecture)


    def forward(self, x):
        x = self.DiscriminatorArchitecture(x)
        return x

# %%
class Model:
    def __init__(self, generator_channels=3, discriminator_channels=3, num_res_blocks=6):
        self.generator_channels = generator_channels
        self.discriminator_channels = discriminator_channels
        self.num_res_blocks = num_res_blocks

    def create_model(self):
        generatorNetwork_A2B = Generator(self.generator_channels, num_ResnetBlocks = self.num_res_blocks)
        generatorNetwork_B2A = Generator(self.generator_channels, num_ResnetBlocks = self.num_res_blocks)
        discriminatorNetwork_A = Discriminator(self.discriminator_channels)
        discriminatorNetwork_B = Discriminator(self.discriminator_channels)

        if torch.cuda.is_available():
            generatorNetwork_A2B.cuda()
            generatorNetwork_B2A.cuda()
            discriminatorNetwork_A.cuda()
            discriminatorNetwork_B.cuda()
            print("Network moved to GPU")
        else:
            print("Network moved to CPU as no GPU devices were identified")


        generatorNetwork_A2B.apply(weights_init_normal)
        generatorNetwork_B2A.apply(weights_init_normal)
        discriminatorNetwork_A.apply(weights_init_normal)
        discriminatorNetwork_B.apply(weights_init_normal)

        return generatorNetwork_A2B,generatorNetwork_B2A,discriminatorNetwork_A,discriminatorNetwork_B

# %%
#@markdown ### Hyper parameters
input_numChannels = 3
batch_size   = 8                         
num_epochs   = 5000
learningRate = 0.001                      
decay_epoch  = int(round(0.6*num_epochs)) 
image_size   = 128

# %%
D = DIODEDataset()

# %%
mod = Model()
gen_A2B,gen_B2A,disc_A,disc_B = mod.create_model()
# Out:
# Network moved to GPU

# %%
#@markdown ### Define Generator parameters
generator_params = list(gen_A2B.parameters())+ list(gen_B2A.parameters())

# %%
def gen_images():
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    
    images_RGB, images_Depth = next(iter(D))
    images_RGB, images_Depth = scale(images_RGB), scale(images_Depth)
    
    images_RGB = images_RGB.to(device)
    images_Depth = images_Depth.to(device)
    
    fake_Depth = gen_A2B(images_RGB)
    fake_Depth = fake_Depth.detach()
    
    plt.figure(figsize=(15, 15))
    display_list = [images_RGB.cpu().permute(1, 2, 0), images_Depth.cpu().permute(1, 2, 0), fake_Depth.cpu().permute(1, 2, 0)]
    
    for i in range(3):
       display_list[i] = display_list[i] * 0.5 + 0.5
    title = ['RGB Image', 'Depth Image', 'Predicted Image']


    plt.subplot(1, 3, 1)
    plt.title('RGB Image')
    plt.imshow(display_list[0])
    plt.axis('off')

    plt.subplot(1, 3, 2)
    plt.title('Depth (Real) Image')
    plt.imshow(display_list[1][:,:,0], cmap='plasma')
    plt.axis('off')

    plt.subplot(1, 3, 3)
    plt.title('Depth (Estimated) Image')
    plt.imshow(display_list[2][:,:,0], cmap='plasma')
    plt.axis('off')

    plt.show()

# %%
gen_images()

# %%
#@markdown ### Define Optimizers and Learning Rate Schedulers
optimizer_gen = optim.RMSprop(generator_params, learningRate)
optimizer_disc_A = torch.optim.RMSprop(disc_A.parameters(),learningRate)
optimizer_disc_B = torch.optim.RMSprop(disc_B.parameters(), learningRate)

learningRate_scheduler_gen = torch.optim.lr_scheduler.LambdaLR(optimizer_gen,lr_lambda = LambdaLR(num_epochs,decay_epoch).step)
learningRate_scheduler_disc_A = torch.optim.lr_scheduler.LambdaLR(optimizer_disc_A, lr_lambda = LambdaLR(num_epochs,decay_epoch).step)
learningRate_scheduler_disc_B = torch.optim.lr_scheduler.LambdaLR(optimizer_disc_B, lr_lambda = LambdaLR(num_epochs,decay_epoch).step)

# %%
#@markdown ### Define the training loop
def training_loop(dataloader, test_dataloader, n_epochs=1000):
    print_every = 10
    losses = []
    test_iter = iter(test_dataloader)
    fixed_RGB, fixed_Depth = next(test_iter)
    fixed_RGB = scale(fixed_RGB)
    fixed_Depth = scale(fixed_Depth)
    
    train_iter = iter(dataloader)
    batches_per_epoch = 4

    for epoch in range(1, n_epochs+1):
        if epoch % batches_per_epoch == 0:
            train_iter = iter(dataloader)

        images_RGB, images_Depth = next(train_iter)
        images_RGB = scale(images_RGB)
        images_Depth = scale(images_Depth)


        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        images_RGB = images_RGB.to(device)
        images_Depth = images_Depth.to(device)
#-------------------------------------Discriminator Training-----------------------------------------------------#

        # optimizers are initialized to zero so that they don't carry forward the errors form previous epochs. Basically to
        # to avoid any accumulation
        optimizer_disc_A.zero_grad()

        # Discriminator-A is initially checked for its performance with real image
        out_RGB = disc_A(images_RGB)
        disc_A_real_loss = real_mse_loss(out_RGB)

        # A fake image is generated by the generator to check the Discriminator's performance with fake image
        fake_RGB = gen_B2A(images_Depth)


        out_RGB = disc_A(fake_RGB)
        disc_A_fake_loss = fake_mse_loss(out_RGB)

        # Losses produced while the above operations are added which is the total loss of the Discriminator-A. It is backpropogated
        disc_A_loss = disc_A_real_loss + disc_A_fake_loss
        disc_A_loss.backward()
        optimizer_disc_A.step()

        # Same operations as mentioned above are now performed on Discriminator-B
        optimizer_disc_B.zero_grad()

        out_Depth = disc_B(images_Depth)
        disc_B_real_loss = real_mse_loss(out_Depth)

        fake_Depth = gen_A2B(images_RGB)

        out_Depth = disc_B(fake_Depth)
        disc_B_fake_loss = fake_mse_loss(out_Depth)


        disc_B_loss = disc_B_real_loss + disc_B_fake_loss
        disc_B_loss.backward()
        optimizer_disc_B.step()

#------------------------------------------Generator Training---------------------------------------------------#

        optimizer_gen.zero_grad()

        # An image is produced from the generator (in this case generator-B2A is being trained) is produced to check how well it can
        fake_RGB = gen_B2A(images_Depth)

        # The generated image is then fed to discrminator to check the fakeness and the MSE loss is received
        out_RGB = disc_A(fake_RGB)
        gen_B2A_loss = real_mse_loss(out_RGB)

        # To check the consistency, the generated image is fed to other generator(A2B in this case) and reconstructed image is received
        reconstructed_Depth = gen_A2B(fake_RGB)
        # Reconstruction loss is received by comparing two images as mentioned in step(4) of training generators
        reconstructed_Depth_loss = cycle_consistency_loss(images_Depth, reconstructed_Depth, lambda_weight=10)


        # Same operations are done, but this time to train gen_A2B
        fake_Depth = gen_A2B(images_RGB)


        out_Depth = disc_B(fake_Depth)
        gen_A2B_loss = real_mse_loss(out_Depth)


        reconstructed_RGB = gen_B2A(fake_Depth)
        reconstructed_RGB_loss = cycle_consistency_loss(images_RGB, reconstructed_RGB, lambda_weight=10)

        # Losses from both the generators are received and propogated backwards
        g_total_loss = gen_B2A_loss + gen_A2B_loss + reconstructed_Depth_loss + reconstructed_RGB_loss
        g_total_loss.backward()
        optimizer_gen.step()

        # Weight decay as mentioned earlier
        learningRate_scheduler_gen.step()
        learningRate_scheduler_disc_A.step()
        learningRate_scheduler_disc_B.step()



        if epoch % print_every == 0:

            losses.append((disc_A_loss.item(), disc_B_loss.item(), g_total_loss.item()))
            print('Epoch [{:5d}/{:5d}] | d_X_loss: {:6.4f} | d_Y_loss: {:6.4f} | g_total_loss: {:6.4f}'.format(
                    epoch, n_epochs, disc_A_loss.item(), disc_B_loss.item(), g_total_loss.item()))

        # A training sample is saved every given time to check the performance of our network
        sample_every=100

        if epoch % sample_every == 0:
            gen_B2A.eval()
            gen_A2B.eval()
            gen_B2A.train()
            gen_A2B.train()

        # Models are saved after every given number of epochs
        checkpoint_every=100
        # Save the model parameters
        if epoch % checkpoint_every == 0:
            checkpoint(epoch, gen_A2B, gen_B2A, disc_A, disc_B)

    return losses

# %%
losses = training_loop(D, D, n_epochs=num_epochs)
# Out:
# Epoch [   10/ 5000] | d_X_loss: 2.1391 | d_Y_loss: 0.7033 | g_total_loss: 9.0467
# Epoch [   20/ 5000] | d_X_loss: 0.9451 | d_Y_loss: 0.6687 | g_total_loss: 5.3216
# Epoch [   30/ 5000] | d_X_loss: 0.6926 | d_Y_loss: 0.6090 | g_total_loss: 7.3725
# Epoch [   40/ 5000] | d_X_loss: 0.6387 | d_Y_loss: 0.5362 | g_total_loss: 4.4265
# Epoch [   50/ 5000] | d_X_loss: 0.5688 | d_Y_loss: 0.2466 | g_total_loss: 4.6194
# Epoch [   60/ 5000] | d_X_loss: 0.6948 | d_Y_loss: 0.2694 | g_total_loss: 4.1470
# Epoch [   70/ 5000] | d_X_loss: 5.6465 | d_Y_loss: 0.1588 | g_total_loss: 5.9470
# Epoch [   80/ 5000] | d_X_loss: 2.0544 | d_Y_loss: 0.2793 | g_total_loss: 3.9064
# Epoch [   90/ 5000] | d_X_loss: 2.0672 | d_Y_loss: 0.1139 | g_total_loss: 4.4530
# Epoch [  100/ 5000] | d_X_loss: 3.5033 | d_Y_loss: 0.2261 | g_total_loss: 4.1685
# Epoch [  110/ 5000] | d_X_loss: 2.1545 | d_Y_loss: 0.2933 | g_total_loss: 4.5163
# Epoch [  120/ 5000] | d_X_loss: 2.9148 | d_Y_loss: 0.1410 | g_total_loss: 4.0064
# Epoch [  130/ 5000] | d_X_loss: 1.2220 | d_Y_loss: 0.2109 | g_total_loss: 4.3274
# Epoch [  140/ 5000] | d_X_loss: 4.7845 | d_Y_loss: 0.6431 | g_total_loss: 5.3661
# Epoch [  150/ 5000] | d_X_loss: 0.4305 | d_Y_loss: 1.6704 | g_total_loss: 6.8472
# Epoch [  160/ 5000] | d_X_loss: 5.0430 | d_Y_loss: 2.9143 | g_total_loss: 8.9282
# Epoch [  170/ 5000] | d_X_loss: 2.5729 | d_Y_loss: 0.4356 | g_total_loss: 5.5623
# Epoch [  180/ 5000] | d_X_loss: 0.8659 | d_Y_loss: 0.5196 | g_total_loss: 4.5405
# Epoch [  190/ 5000] | d_X_loss: 1.3231 | d_Y_loss: 0.4390 | g_total_loss: 6.2917
# Epoch [  200/ 5000] | d_X_loss: 3.2342 | d_Y_loss: 0.9952 | g_total_loss: 7.2479
# Epoch [  210/ 5000] | d_X_loss: 0.4086 | d_Y_loss: 0.6326 | g_total_loss: 3.9032
# Epoch [  220/ 5000] | d_X_loss: 20.5761 | d_Y_loss: 2.6319 | g_total_loss: 14.3339
# Epoch [  230/ 5000] | d_X_loss: 2.0970 | d_Y_loss: 0.1190 | g_total_loss: 4.9532
# Epoch [  240/ 5000] | d_X_loss: 0.6193 | d_Y_loss: 0.1844 | g_total_loss: 4.5085
# Epoch [  250/ 5000] | d_X_loss: 0.6561 | d_Y_loss: 0.5248 | g_total_loss: 6.2568
# Epoch [  260/ 5000] | d_X_loss: 10.0102 | d_Y_loss: 0.1842 | g_total_loss: 12.5722
# Epoch [  270/ 5000] | d_X_loss: 1.9870 | d_Y_loss: 6.0983 | g_total_loss: 6.9381
# Epoch [  280/ 5000] | d_X_loss: 0.7128 | d_Y_loss: 0.3755 | g_total_loss: 5.0553
# Epoch [  290/ 5000] | d_X_loss: 1.1776 | d_Y_loss: 0.3313 | g_total_loss: 5.2232
# Epoch [  300/ 5000] | d_X_loss: 19.5855 | d_Y_loss: 0.5688 | g_total_loss: 9.2356
# Epoch [  310/ 5000] | d_X_loss: 1.1420 | d_Y_loss: 0.8822 | g_total_loss: 4.4538
# Epoch [  320/ 5000] | d_X_loss: 0.5149 | d_Y_loss: 0.1388 | g_total_loss: 4.1750
# Epoch [  330/ 5000] | d_X_loss: 3.4850 | d_Y_loss: 1.8824 | g_total_loss: 6.3377
# Epoch [  340/ 5000] | d_X_loss: 1.7503 | d_Y_loss: 0.6964 | g_total_loss: 3.5279
# Epoch [  350/ 5000] | d_X_loss: 0.9774 | d_Y_loss: 1.2947 | g_total_loss: 3.7066
# Epoch [  360/ 5000] | d_X_loss: 1.4543 | d_Y_loss: 0.3533 | g_total_loss: 4.4633
# Epoch [  370/ 5000] | d_X_loss: 5.0227 | d_Y_loss: 1.0586 | g_total_loss: 5.4015
# Epoch [  380/ 5000] | d_X_loss: 1.8834 | d_Y_loss: 2.8959 | g_total_loss: 3.8080
# Epoch [  390/ 5000] | d_X_loss: 0.4545 | d_Y_loss: 0.1137 | g_total_loss: 4.0610
# Epoch [  400/ 5000] | d_X_loss: 7.6900 | d_Y_loss: 1.1155 | g_total_loss: 9.8629
# Epoch [  410/ 5000] | d_X_loss: 4.3032 | d_Y_loss: 0.3439 | g_total_loss: 6.1820
# Epoch [  420/ 5000] | d_X_loss: 0.4448 | d_Y_loss: 1.0200 | g_total_loss: 4.3785
# Epoch [  430/ 5000] | d_X_loss: 14.5797 | d_Y_loss: 2.5770 | g_total_loss: 8.5714
# Epoch [  440/ 5000] | d_X_loss: 0.2433 | d_Y_loss: 0.8131 | g_total_loss: 3.6202
# Epoch [  450/ 5000] | d_X_loss: 3.5220 | d_Y_loss: 0.3193 | g_total_loss: 6.2447
# Epoch [  460/ 5000] | d_X_loss: 0.4150 | d_Y_loss: 0.1239 | g_total_loss: 4.8091
# Epoch [  470/ 5000] | d_X_loss: 2.1192 | d_Y_loss: 0.5631 | g_total_loss: 5.0501
# Epoch [  480/ 5000] | d_X_loss: 1.6698 | d_Y_loss: 0.7023 | g_total_loss: 5.4043
# Epoch [  490/ 5000] | d_X_loss: 0.9998 | d_Y_loss: 0.6510 | g_total_loss: 4.1680
# Epoch [  500/ 5000] | d_X_loss: 1.2267 | d_Y_loss: 0.5254 | g_total_loss: 5.7123
# Epoch [  510/ 5000] | d_X_loss: 3.3178 | d_Y_loss: 0.7019 | g_total_loss: 5.1335
# Epoch [  520/ 5000] | d_X_loss: 0.8736 | d_Y_loss: 4.4860 | g_total_loss: 31.6058
# Epoch [  530/ 5000] | d_X_loss: 0.4374 | d_Y_loss: 0.3770 | g_total_loss: 4.9108
# Epoch [  540/ 5000] | d_X_loss: 5.9937 | d_Y_loss: 0.3780 | g_total_loss: 4.9976
# Epoch [  550/ 5000] | d_X_loss: 0.9643 | d_Y_loss: 0.2677 | g_total_loss: 3.5123
# Epoch [  560/ 5000] | d_X_loss: 0.7086 | d_Y_loss: 0.5041 | g_total_loss: 4.4004
# Epoch [  570/ 5000] | d_X_loss: 0.5429 | d_Y_loss: 0.4072 | g_total_loss: 3.9864
# Epoch [  580/ 5000] | d_X_loss: 0.6672 | d_Y_loss: 0.8038 | g_total_loss: 4.3969
# Epoch [  590/ 5000] | d_X_loss: 0.4548 | d_Y_loss: 0.3930 | g_total_loss: 4.2344
# Epoch [  600/ 5000] | d_X_loss: 0.1630 | d_Y_loss: 0.8292 | g_total_loss: 4.7955
# Epoch [  610/ 5000] | d_X_loss: 0.4350 | d_Y_loss: 0.2135 | g_total_loss: 4.7916
# Epoch [  620/ 5000] | d_X_loss: 0.2119 | d_Y_loss: 1.7836 | g_total_loss: 4.0725
# Epoch [  630/ 5000] | d_X_loss: 76.2467 | d_Y_loss: 0.2955 | g_total_loss: 29.9661
# Epoch [  640/ 5000] | d_X_loss: 0.4999 | d_Y_loss: 40.0330 | g_total_loss: 45.0592
# Epoch [  650/ 5000] | d_X_loss: 0.5605 | d_Y_loss: 0.4606 | g_total_loss: 6.9218
# Epoch [  660/ 5000] | d_X_loss: 0.1588 | d_Y_loss: 0.4437 | g_total_loss: 6.9889
# Epoch [  670/ 5000] | d_X_loss: 0.4865 | d_Y_loss: 0.4212 | g_total_loss: 6.0931
# Epoch [  680/ 5000] | d_X_loss: 0.2823 | d_Y_loss: 0.5599 | g_total_loss: 6.2256
# Epoch [  690/ 5000] | d_X_loss: 0.4483 | d_Y_loss: 0.4533 | g_total_loss: 5.5479
# Epoch [  700/ 5000] | d_X_loss: 0.6898 | d_Y_loss: 0.5264 | g_total_loss: 6.4321
# Epoch [  710/ 5000] | d_X_loss: 0.4018 | d_Y_loss: 0.4997 | g_total_loss: 3.8410
# Epoch [  720/ 5000] | d_X_loss: 0.3367 | d_Y_loss: 0.5369 | g_total_loss: 5.2203
# Epoch [  730/ 5000] | d_X_loss: 0.4944 | d_Y_loss: 0.6119 | g_total_loss: 3.6419
# Epoch [  740/ 5000] | d_X_loss: 2.4965 | d_Y_loss: 0.6910 | g_total_loss: 6.8740
# Epoch [  750/ 5000] | d_X_loss: 0.2710 | d_Y_loss: 0.5595 | g_total_loss: 3.7194
# Epoch [  760/ 5000] | d_X_loss: 0.1638 | d_Y_loss: 0.6175 | g_total_loss: 4.0922
# Epoch [  770/ 5000] | d_X_loss: 0.5040 | d_Y_loss: 0.5331 | g_total_loss: 3.0239
# Epoch [  780/ 5000] | d_X_loss: 0.2110 | d_Y_loss: 0.6417 | g_total_loss: 3.4222
# Epoch [  790/ 5000] | d_X_loss: 0.3412 | d_Y_loss: 0.5732 | g_total_loss: 2.8930
# Epoch [  800/ 5000] | d_X_loss: 0.3200 | d_Y_loss: 0.6424 | g_total_loss: 6.1069
# Epoch [  810/ 5000] | d_X_loss: 0.3033 | d_Y_loss: 0.4555 | g_total_loss: 4.7378
# Epoch [  820/ 5000] | d_X_loss: 1.8772 | d_Y_loss: 0.7349 | g_total_loss: 3.1265
# Epoch [  830/ 5000] | d_X_loss: 0.6083 | d_Y_loss: 0.6138 | g_total_loss: 2.7025
# Epoch [  840/ 5000] | d_X_loss: 0.1550 | d_Y_loss: 0.8931 | g_total_loss: 4.5319
# Epoch [  850/ 5000] | d_X_loss: 0.2412 | d_Y_loss: 0.5153 | g_total_loss: 3.9026
# Epoch [  860/ 5000] | d_X_loss: 3.1390 | d_Y_loss: 0.7080 | g_total_loss: 3.9022
# Epoch [  870/ 5000] | d_X_loss: 0.3530 | d_Y_loss: 1.5580 | g_total_loss: 2.9753
# Epoch [  880/ 5000] | d_X_loss: 0.3192 | d_Y_loss: 0.4539 | g_total_loss: 3.8531
# Epoch [  890/ 5000] | d_X_loss: 1.3626 | d_Y_loss: 0.5052 | g_total_loss: 2.6416
# Epoch [  900/ 5000] | d_X_loss: 0.1759 | d_Y_loss: 1.5128 | g_total_loss: 3.8411
# Epoch [  910/ 5000] | d_X_loss: 0.2409 | d_Y_loss: 0.7316 | g_total_loss: 3.4818
# Epoch [  920/ 5000] | d_X_loss: 0.4877 | d_Y_loss: 0.5629 | g_total_loss: 3.5972
# Epoch [  930/ 5000] | d_X_loss: 0.1280 | d_Y_loss: 1.4581 | g_total_loss: 3.0395
# Epoch [  940/ 5000] | d_X_loss: 0.8006 | d_Y_loss: 0.5581 | g_total_loss: 8.1217
# Epoch [  950/ 5000] | d_X_loss: 0.2323 | d_Y_loss: 1.6356 | g_total_loss: 5.2602
# Epoch [  960/ 5000] | d_X_loss: 0.7958 | d_Y_loss: 0.5263 | g_total_loss: 4.0823
# Epoch [  970/ 5000] | d_X_loss: 0.3929 | d_Y_loss: 1.0730 | g_total_loss: 3.9869
# Epoch [  980/ 5000] | d_X_loss: 4.8762 | d_Y_loss: 0.4737 | g_total_loss: 5.3880
# Epoch [  990/ 5000] | d_X_loss: 0.1633 | d_Y_loss: 0.6435 | g_total_loss: 3.1978
# Epoch [ 1000/ 5000] | d_X_loss: 0.0927 | d_Y_loss: 1.1132 | g_total_loss: 3.4297
# Epoch [ 1010/ 5000] | d_X_loss: 0.4419 | d_Y_loss: 1.8563 | g_total_loss: 3.4067
# Epoch [ 1020/ 5000] | d_X_loss: 0.4958 | d_Y_loss: 0.3326 | g_total_loss: 3.6737
# Epoch [ 1030/ 5000] | d_X_loss: 0.4668 | d_Y_loss: 0.3271 | g_total_loss: 2.9557
# Epoch [ 1040/ 5000] | d_X_loss: 0.4376 | d_Y_loss: 2.0104 | g_total_loss: 3.5554
# Epoch [ 1050/ 5000] | d_X_loss: 0.3782 | d_Y_loss: 0.6557 | g_total_loss: 2.8081
# Epoch [ 1060/ 5000] | d_X_loss: 0.2520 | d_Y_loss: 0.3256 | g_total_loss: 3.6059
# Epoch [ 1070/ 5000] | d_X_loss: 0.7935 | d_Y_loss: 1.1291 | g_total_loss: 5.3475
# Epoch [ 1080/ 5000] | d_X_loss: 2.0446 | d_Y_loss: 1.3332 | g_total_loss: 4.0377
# Epoch [ 1090/ 5000] | d_X_loss: 0.7366 | d_Y_loss: 0.3795 | g_total_loss: 3.7459
# Epoch [ 1100/ 5000] | d_X_loss: 0.7427 | d_Y_loss: 1.2130 | g_total_loss: 6.1313
# Epoch [ 1110/ 5000] | d_X_loss: 0.3037 | d_Y_loss: 0.5450 | g_total_loss: 5.8985
# Epoch [ 1120/ 5000] | d_X_loss: 0.7973 | d_Y_loss: 0.3579 | g_total_loss: 4.9855
# Epoch [ 1130/ 5000] | d_X_loss: 6.2145 | d_Y_loss: 1.0316 | g_total_loss: 6.6884
# Epoch [ 1140/ 5000] | d_X_loss: 0.6263 | d_Y_loss: 0.7458 | g_total_loss: 4.3063
# Epoch [ 1150/ 5000] | d_X_loss: 0.3173 | d_Y_loss: 0.5530 | g_total_loss: 5.2164
# Epoch [ 1160/ 5000] | d_X_loss: 0.2459 | d_Y_loss: 0.3561 | g_total_loss: 4.2667
# Epoch [ 1170/ 5000] | d_X_loss: 0.4061 | d_Y_loss: 1.0480 | g_total_loss: 3.2998
# Epoch [ 1180/ 5000] | d_X_loss: 0.2755 | d_Y_loss: 0.9519 | g_total_loss: 4.2019
# Epoch [ 1190/ 5000] | d_X_loss: 0.2968 | d_Y_loss: 0.4604 | g_total_loss: 5.5284
# Epoch [ 1200/ 5000] | d_X_loss: 1.3408 | d_Y_loss: 0.9678 | g_total_loss: 4.5797
# Epoch [ 1210/ 5000] | d_X_loss: 0.1743 | d_Y_loss: 1.1245 | g_total_loss: 3.7954
# Epoch [ 1220/ 5000] | d_X_loss: 1.3155 | d_Y_loss: 0.3799 | g_total_loss: 5.6741
# Epoch [ 1230/ 5000] | d_X_loss: 0.1888 | d_Y_loss: 2.2540 | g_total_loss: 7.6700
# Epoch [ 1240/ 5000] | d_X_loss: 0.1502 | d_Y_loss: 0.3207 | g_total_loss: 5.5119
# Epoch [ 1250/ 5000] | d_X_loss: 0.6090 | d_Y_loss: 0.5211 | g_total_loss: 6.3941
# Epoch [ 1260/ 5000] | d_X_loss: 0.7249 | d_Y_loss: 0.4520 | g_total_loss: 3.8958
# Epoch [ 1270/ 5000] | d_X_loss: 0.6963 | d_Y_loss: 0.4136 | g_total_loss: 6.4132
# Epoch [ 1280/ 5000] | d_X_loss: 0.3457 | d_Y_loss: 0.5229 | g_total_loss: 3.9269
# Epoch [ 1290/ 5000] | d_X_loss: 0.2165 | d_Y_loss: 0.4305 | g_total_loss: 3.8438
# Epoch [ 1300/ 5000] | d_X_loss: 0.0749 | d_Y_loss: 0.2734 | g_total_loss: 3.5422
# Epoch [ 1310/ 5000] | d_X_loss: 0.0487 | d_Y_loss: 0.3658 | g_total_loss: 3.8770
# Epoch [ 1320/ 5000] | d_X_loss: 0.1365 | d_Y_loss: 3.1638 | g_total_loss: 8.5485
# Epoch [ 1330/ 5000] | d_X_loss: 0.1496 | d_Y_loss: 0.4261 | g_total_loss: 2.9689
# Epoch [ 1340/ 5000] | d_X_loss: 2.1443 | d_Y_loss: 0.8479 | g_total_loss: 3.0448
# Epoch [ 1350/ 5000] | d_X_loss: 0.3929 | d_Y_loss: 0.4813 | g_total_loss: 7.6632
# Epoch [ 1360/ 5000] | d_X_loss: 0.2349 | d_Y_loss: 0.5424 | g_total_loss: 3.6079
# Epoch [ 1370/ 5000] | d_X_loss: 0.0860 | d_Y_loss: 0.7421 | g_total_loss: 3.1971
# Epoch [ 1380/ 5000] | d_X_loss: 0.0844 | d_Y_loss: 0.8756 | g_total_loss: 3.4741
# Epoch [ 1390/ 5000] | d_X_loss: 0.1851 | d_Y_loss: 0.3137 | g_total_loss: 2.9054
# Epoch [ 1400/ 5000] | d_X_loss: 0.6734 | d_Y_loss: 0.3113 | g_total_loss: 4.1206
# Epoch [ 1410/ 5000] | d_X_loss: 0.7913 | d_Y_loss: 1.5087 | g_total_loss: 6.3346
# Epoch [ 1420/ 5000] | d_X_loss: 3.2914 | d_Y_loss: 2.8523 | g_total_loss: 4.8805
# Epoch [ 1430/ 5000] | d_X_loss: 1.0620 | d_Y_loss: 0.4733 | g_total_loss: 4.1251
# Epoch [ 1440/ 5000] | d_X_loss: 3.2402 | d_Y_loss: 0.5821 | g_total_loss: 4.8467
# Epoch [ 1450/ 5000] | d_X_loss: 0.4410 | d_Y_loss: 0.4760 | g_total_loss: 3.1517
# Epoch [ 1460/ 5000] | d_X_loss: 3.9095 | d_Y_loss: 0.6638 | g_total_loss: 4.3113
# Epoch [ 1470/ 5000] | d_X_loss: 0.3976 | d_Y_loss: 0.5196 | g_total_loss: 3.2070
# Epoch [ 1480/ 5000] | d_X_loss: 0.6201 | d_Y_loss: 0.6542 | g_total_loss: 3.8452
# Epoch [ 1490/ 5000] | d_X_loss: 0.2596 | d_Y_loss: 0.4708 | g_total_loss: 2.8467
# Epoch [ 1500/ 5000] | d_X_loss: 1.6626 | d_Y_loss: 0.8761 | g_total_loss: 3.4617
# Epoch [ 1510/ 5000] | d_X_loss: 0.2025 | d_Y_loss: 0.6056 | g_total_loss: 3.1606
# Epoch [ 1520/ 5000] | d_X_loss: 1.0919 | d_Y_loss: 0.6480 | g_total_loss: 2.7942
# Epoch [ 1530/ 5000] | d_X_loss: 0.5918 | d_Y_loss: 0.5442 | g_total_loss: 3.3360
# Epoch [ 1540/ 5000] | d_X_loss: 1.9445 | d_Y_loss: 3.1127 | g_total_loss: 5.6077
# Epoch [ 1550/ 5000] | d_X_loss: 0.8581 | d_Y_loss: 0.3612 | g_total_loss: 9.3895
# Epoch [ 1560/ 5000] | d_X_loss: 0.6511 | d_Y_loss: 0.4079 | g_total_loss: 3.4583
# Epoch [ 1570/ 5000] | d_X_loss: 0.7550 | d_Y_loss: 0.3419 | g_total_loss: 2.8138
# Epoch [ 1580/ 5000] | d_X_loss: 1.1893 | d_Y_loss: 1.6376 | g_total_loss: 5.7506
# Epoch [ 1590/ 5000] | d_X_loss: 0.4648 | d_Y_loss: 0.3862 | g_total_loss: 3.4531
# Epoch [ 1600/ 5000] | d_X_loss: 0.8120 | d_Y_loss: 0.6869 | g_total_loss: 3.6780
# Epoch [ 1610/ 5000] | d_X_loss: 0.5025 | d_Y_loss: 0.9033 | g_total_loss: 2.6580
# Epoch [ 1620/ 5000] | d_X_loss: 0.8576 | d_Y_loss: 0.5223 | g_total_loss: 3.1257
# Epoch [ 1630/ 5000] | d_X_loss: 0.5400 | d_Y_loss: 0.1834 | g_total_loss: 3.2586
# Epoch [ 1640/ 5000] | d_X_loss: 0.2560 | d_Y_loss: 0.7959 | g_total_loss: 5.1050
# Epoch [ 1650/ 5000] | d_X_loss: 0.2155 | d_Y_loss: 1.5140 | g_total_loss: 2.9379
# Epoch [ 1660/ 5000] | d_X_loss: 0.0972 | d_Y_loss: 0.3514 | g_total_loss: 4.0282
# Epoch [ 1670/ 5000] | d_X_loss: 0.2299 | d_Y_loss: 0.2564 | g_total_loss: 2.6422
# Epoch [ 1680/ 5000] | d_X_loss: 0.6378 | d_Y_loss: 1.2805 | g_total_loss: 3.2782
# Epoch [ 1690/ 5000] | d_X_loss: 0.1327 | d_Y_loss: 0.4437 | g_total_loss: 3.5972
# Epoch [ 1700/ 5000] | d_X_loss: 0.7088 | d_Y_loss: 0.3684 | g_total_loss: 3.5219
# Epoch [ 1710/ 5000] | d_X_loss: 0.7211 | d_Y_loss: 1.5536 | g_total_loss: 2.5234
# Epoch [ 1720/ 5000] | d_X_loss: 0.4836 | d_Y_loss: 0.5555 | g_total_loss: 4.1165
# Epoch [ 1730/ 5000] | d_X_loss: 0.4492 | d_Y_loss: 0.5548 | g_total_loss: 4.1669
# Epoch [ 1740/ 5000] | d_X_loss: 0.2176 | d_Y_loss: 1.8365 | g_total_loss: 2.7923
# Epoch [ 1750/ 5000] | d_X_loss: 0.2049 | d_Y_loss: 0.3684 | g_total_loss: 3.1828
# Epoch [ 1760/ 5000] | d_X_loss: 0.6702 | d_Y_loss: 0.3684 | g_total_loss: 2.9741
# Epoch [ 1770/ 5000] | d_X_loss: 1.0469 | d_Y_loss: 1.7398 | g_total_loss: 2.5506
# Epoch [ 1780/ 5000] | d_X_loss: 1.1029 | d_Y_loss: 0.2944 | g_total_loss: 3.3659
# Epoch [ 1790/ 5000] | d_X_loss: 0.2240 | d_Y_loss: 0.5152 | g_total_loss: 2.3198
# Epoch [ 1800/ 5000] | d_X_loss: 0.4902 | d_Y_loss: 0.8280 | g_total_loss: 3.1260
# Epoch [ 1810/ 5000] | d_X_loss: 0.6755 | d_Y_loss: 0.3095 | g_total_loss: 7.6259
# Epoch [ 1820/ 5000] | d_X_loss: 2.3235 | d_Y_loss: 0.7155 | g_total_loss: 7.3542
# Epoch [ 1830/ 5000] | d_X_loss: 0.1503 | d_Y_loss: 0.4751 | g_total_loss: 7.2048
# Epoch [ 1840/ 5000] | d_X_loss: 0.1233 | d_Y_loss: 0.6574 | g_total_loss: 5.8227
# Epoch [ 1850/ 5000] | d_X_loss: 0.0811 | d_Y_loss: 0.9380 | g_total_loss: 7.3414
# Epoch [ 1860/ 5000] | d_X_loss: 0.1418 | d_Y_loss: 0.1762 | g_total_loss: 5.9747
# Epoch [ 1870/ 5000] | d_X_loss: 0.0978 | d_Y_loss: 0.2457 | g_total_loss: 5.1505
# Epoch [ 1880/ 5000] | d_X_loss: 0.1204 | d_Y_loss: 3.3459 | g_total_loss: 4.8538
# Epoch [ 1890/ 5000] | d_X_loss: 0.1548 | d_Y_loss: 0.5064 | g_total_loss: 4.7457
# Epoch [ 1900/ 5000] | d_X_loss: 0.1460 | d_Y_loss: 0.2455 | g_total_loss: 5.2345
# Epoch [ 1910/ 5000] | d_X_loss: 0.2311 | d_Y_loss: 0.1919 | g_total_loss: 3.9463
# Epoch [ 1920/ 5000] | d_X_loss: 0.0827 | d_Y_loss: 0.2319 | g_total_loss: 4.9082
# Epoch [ 1930/ 5000] | d_X_loss: 0.0664 | d_Y_loss: 0.3312 | g_total_loss: 4.2331
# Epoch [ 1940/ 5000] | d_X_loss: 0.1670 | d_Y_loss: 0.1343 | g_total_loss: 4.3609
# Epoch [ 1950/ 5000] | d_X_loss: 0.0992 | d_Y_loss: 0.5653 | g_total_loss: 5.1360
# Epoch [ 1960/ 5000] | d_X_loss: 0.1040 | d_Y_loss: 0.2958 | g_total_loss: 7.0818
# Epoch [ 1970/ 5000] | d_X_loss: 0.1735 | d_Y_loss: 1.5523 | g_total_loss: 3.4284
# Epoch [ 1980/ 5000] | d_X_loss: 0.5568 | d_Y_loss: 0.2103 | g_total_loss: 4.9634
# Epoch [ 1990/ 5000] | d_X_loss: 0.1724 | d_Y_loss: 0.5138 | g_total_loss: 3.4432
# Epoch [ 2000/ 5000] | d_X_loss: 0.3916 | d_Y_loss: 0.1388 | g_total_loss: 5.1768
# Epoch [ 2010/ 5000] | d_X_loss: 0.2022 | d_Y_loss: 0.5193 | g_total_loss: 3.6261
# Epoch [ 2020/ 5000] | d_X_loss: 0.2812 | d_Y_loss: 0.2990 | g_total_loss: 4.4053
# Epoch [ 2030/ 5000] | d_X_loss: 0.3581 | d_Y_loss: 0.6393 | g_total_loss: 3.5700
# Epoch [ 2040/ 5000] | d_X_loss: 0.7454 | d_Y_loss: 0.0922 | g_total_loss: 4.4522
# Epoch [ 2050/ 5000] | d_X_loss: 0.2166 | d_Y_loss: 2.1416 | g_total_loss: 5.0778
# Epoch [ 2060/ 5000] | d_X_loss: 0.1995 | d_Y_loss: 0.2541 | g_total_loss: 3.8982
# Epoch [ 2070/ 5000] | d_X_loss: 0.1710 | d_Y_loss: 0.4381 | g_total_loss: 2.7701
# Epoch [ 2080/ 5000] | d_X_loss: 1.2626 | d_Y_loss: 0.3668 | g_total_loss: 4.6680
# Epoch [ 2090/ 5000] | d_X_loss: 0.3645 | d_Y_loss: 1.0619 | g_total_loss: 3.2591
# Epoch [ 2100/ 5000] | d_X_loss: 0.2960 | d_Y_loss: 0.8091 | g_total_loss: 5.4916
# Epoch [ 2110/ 5000] | d_X_loss: 0.4672 | d_Y_loss: 0.4962 | g_total_loss: 3.1193
# Epoch [ 2120/ 5000] | d_X_loss: 1.2501 | d_Y_loss: 0.6993 | g_total_loss: 6.0949
# Epoch [ 2130/ 5000] | d_X_loss: 0.1278 | d_Y_loss: 1.1663 | g_total_loss: 5.1695
# Epoch [ 2140/ 5000] | d_X_loss: 0.7523 | d_Y_loss: 0.3588 | g_total_loss: 4.4777
# Epoch [ 2150/ 5000] | d_X_loss: 0.2421 | d_Y_loss: 0.8588 | g_total_loss: 3.7049
# Epoch [ 2160/ 5000] | d_X_loss: 0.1576 | d_Y_loss: 2.3447 | g_total_loss: 3.6846
# Epoch [ 2170/ 5000] | d_X_loss: 0.0715 | d_Y_loss: 0.6029 | g_total_loss: 3.3003
# Epoch [ 2180/ 5000] | d_X_loss: 0.4750 | d_Y_loss: 0.3253 | g_total_loss: 4.7215
# Epoch [ 2190/ 5000] | d_X_loss: 0.2761 | d_Y_loss: 0.7029 | g_total_loss: 2.4277
# Epoch [ 2200/ 5000] | d_X_loss: 260.0173 | d_Y_loss: 0.2807 | g_total_loss: 17.6147
# Epoch [ 2210/ 5000] | d_X_loss: 0.3090 | d_Y_loss: 1.1499 | g_total_loss: 7.3690
# Epoch [ 2220/ 5000] | d_X_loss: 0.2327 | d_Y_loss: 0.2275 | g_total_loss: 7.0168
# Epoch [ 2230/ 5000] | d_X_loss: 0.1600 | d_Y_loss: 0.9431 | g_total_loss: 8.3397
# Epoch [ 2240/ 5000] | d_X_loss: 0.1777 | d_Y_loss: 0.2904 | g_total_loss: 5.6613
# Epoch [ 2250/ 5000] | d_X_loss: 0.1237 | d_Y_loss: 0.6862 | g_total_loss: 5.5203
# Epoch [ 2260/ 5000] | d_X_loss: 0.1359 | d_Y_loss: 1.1271 | g_total_loss: 8.7194
# Epoch [ 2270/ 5000] | d_X_loss: 0.0938 | d_Y_loss: 0.0780 | g_total_loss: 5.1815
# Epoch [ 2280/ 5000] | d_X_loss: 0.0782 | d_Y_loss: 0.3526 | g_total_loss: 5.1525
# Epoch [ 2290/ 5000] | d_X_loss: 0.0805 | d_Y_loss: 1.2604 | g_total_loss: 6.8202
# Epoch [ 2300/ 5000] | d_X_loss: 0.0671 | d_Y_loss: 0.5419 | g_total_loss: 4.7960
# Epoch [ 2310/ 5000] | d_X_loss: 0.0651 | d_Y_loss: 0.3014 | g_total_loss: 4.7467
# Epoch [ 2320/ 5000] | d_X_loss: 0.0651 | d_Y_loss: 1.4435 | g_total_loss: 7.1121
# Epoch [ 2330/ 5000] | d_X_loss: 0.0556 | d_Y_loss: 0.1827 | g_total_loss: 4.3095
# Epoch [ 2340/ 5000] | d_X_loss: 0.0752 | d_Y_loss: 0.4421 | g_total_loss: 4.2226
# Epoch [ 2350/ 5000] | d_X_loss: 0.0383 | d_Y_loss: 0.8792 | g_total_loss: 5.5102
# Epoch [ 2360/ 5000] | d_X_loss: 0.0823 | d_Y_loss: 0.1861 | g_total_loss: 4.4566
# Epoch [ 2370/ 5000] | d_X_loss: 0.0409 | d_Y_loss: 1.4514 | g_total_loss: 4.0565
# Epoch [ 2380/ 5000] | d_X_loss: 0.1516 | d_Y_loss: 0.2122 | g_total_loss: 5.1706
# Epoch [ 2390/ 5000] | d_X_loss: 0.0407 | d_Y_loss: 0.5473 | g_total_loss: 4.2923
# Epoch [ 2400/ 5000] | d_X_loss: 0.0756 | d_Y_loss: 0.4773 | g_total_loss: 3.8401
# Epoch [ 2410/ 5000] | d_X_loss: 0.0760 | d_Y_loss: 0.3890 | g_total_loss: 3.4357
# Epoch [ 2420/ 5000] | d_X_loss: 0.2032 | d_Y_loss: 1.7570 | g_total_loss: 3.3879
# Epoch [ 2430/ 5000] | d_X_loss: 0.0298 | d_Y_loss: 0.2052 | g_total_loss: 3.6364
# Epoch [ 2440/ 5000] | d_X_loss: 1.0444 | d_Y_loss: 0.6185 | g_total_loss: 6.8337
# Epoch [ 2450/ 5000] | d_X_loss: 0.0325 | d_Y_loss: 0.9504 | g_total_loss: 3.4201
# Epoch [ 2460/ 5000] | d_X_loss: 0.3652 | d_Y_loss: 0.4562 | g_total_loss: 2.8369
# Epoch [ 2470/ 5000] | d_X_loss: 0.1709 | d_Y_loss: 1.7973 | g_total_loss: 2.8378
# Epoch [ 2480/ 5000] | d_X_loss: 0.1862 | d_Y_loss: 0.3826 | g_total_loss: 3.5705
# Epoch [ 2490/ 5000] | d_X_loss: 0.2272 | d_Y_loss: 0.3073 | g_total_loss: 2.6322
# Epoch [ 2500/ 5000] | d_X_loss: 1.3166 | d_Y_loss: 0.1780 | g_total_loss: 6.3530
# Epoch [ 2510/ 5000] | d_X_loss: 0.2230 | d_Y_loss: 3.3219 | g_total_loss: 3.5241
# Epoch [ 2520/ 5000] | d_X_loss: 2.5934 | d_Y_loss: 0.4258 | g_total_loss: 3.4469
# Epoch [ 2530/ 5000] | d_X_loss: 0.2020 | d_Y_loss: 0.2780 | g_total_loss: 3.9662
# Epoch [ 2540/ 5000] | d_X_loss: 0.5792 | d_Y_loss: 0.2622 | g_total_loss: 3.9785
# Epoch [ 2550/ 5000] | d_X_loss: 0.2869 | d_Y_loss: 0.3781 | g_total_loss: 3.1053
# Epoch [ 2560/ 5000] | d_X_loss: 0.3237 | d_Y_loss: 0.5493 | g_total_loss: 3.5982
# Epoch [ 2570/ 5000] | d_X_loss: 0.1049 | d_Y_loss: 1.4285 | g_total_loss: 2.9934
# Epoch [ 2580/ 5000] | d_X_loss: 0.4339 | d_Y_loss: 0.2228 | g_total_loss: 3.5096
# Epoch [ 2590/ 5000] | d_X_loss: 0.1299 | d_Y_loss: 0.2749 | g_total_loss: 2.7933
# Epoch [ 2600/ 5000] | d_X_loss: 0.6820 | d_Y_loss: 1.1597 | g_total_loss: 3.7128
# Epoch [ 2610/ 5000] | d_X_loss: 0.2509 | d_Y_loss: 0.2329 | g_total_loss: 2.6686
# Epoch [ 2620/ 5000] | d_X_loss: 0.3657 | d_Y_loss: 0.2866 | g_total_loss: 4.7088
# Epoch [ 2630/ 5000] | d_X_loss: 0.1724 | d_Y_loss: 1.5270 | g_total_loss: 5.2917
# Epoch [ 2640/ 5000] | d_X_loss: 0.3637 | d_Y_loss: 0.7746 | g_total_loss: 3.2682
# Epoch [ 2650/ 5000] | d_X_loss: 0.3497 | d_Y_loss: 1.2355 | g_total_loss: 3.0549
# Epoch [ 2660/ 5000] | d_X_loss: 113.3673 | d_Y_loss: 0.7072 | g_total_loss: 124.1030
# Epoch [ 2670/ 5000] | d_X_loss: 0.9701 | d_Y_loss: 0.9856 | g_total_loss: 5.8724
# Epoch [ 2680/ 5000] | d_X_loss: 0.3159 | d_Y_loss: 0.1714 | g_total_loss: 4.4418
# Epoch [ 2690/ 5000] | d_X_loss: 0.2194 | d_Y_loss: 0.2886 | g_total_loss: 4.0960
# Epoch [ 2700/ 5000] | d_X_loss: 0.1850 | d_Y_loss: 0.6358 | g_total_loss: 3.9328
# Epoch [ 2710/ 5000] | d_X_loss: 0.1240 | d_Y_loss: 0.3733 | g_total_loss: 5.2251
# Epoch [ 2720/ 5000] | d_X_loss: 0.1022 | d_Y_loss: 1.8596 | g_total_loss: 10.0040
# Epoch [ 2730/ 5000] | d_X_loss: 0.0883 | d_Y_loss: 0.3653 | g_total_loss: 3.9410
# Epoch [ 2740/ 5000] | d_X_loss: 0.0838 | d_Y_loss: 0.1290 | g_total_loss: 4.2123
# Epoch [ 2750/ 5000] | d_X_loss: 0.0802 | d_Y_loss: 0.1044 | g_total_loss: 4.5183
# Epoch [ 2760/ 5000] | d_X_loss: 0.0911 | d_Y_loss: 0.3145 | g_total_loss: 3.9934
# Epoch [ 2770/ 5000] | d_X_loss: 0.0983 | d_Y_loss: 1.4906 | g_total_loss: 3.4601
# Epoch [ 2780/ 5000] | d_X_loss: 0.1241 | d_Y_loss: 0.1895 | g_total_loss: 4.4414
# Epoch [ 2790/ 5000] | d_X_loss: 0.0994 | d_Y_loss: 0.1250 | g_total_loss: 4.2944
# Epoch [ 2800/ 5000] | d_X_loss: 0.1127 | d_Y_loss: 1.0371 | g_total_loss: 4.4466
# Epoch [ 2810/ 5000] | d_X_loss: 0.1591 | d_Y_loss: 0.3959 | g_total_loss: 3.9909
# Epoch [ 2820/ 5000] | d_X_loss: 0.7367 | d_Y_loss: 0.1931 | g_total_loss: 5.9679
# Epoch [ 2830/ 5000] | d_X_loss: 0.1432 | d_Y_loss: 0.1347 | g_total_loss: 4.5429
# Epoch [ 2840/ 5000] | d_X_loss: 0.4400 | d_Y_loss: 3.7084 | g_total_loss: 5.5808
# Epoch [ 2850/ 5000] | d_X_loss: 0.2093 | d_Y_loss: 0.1066 | g_total_loss: 4.7560
# Epoch [ 2860/ 5000] | d_X_loss: 1.0039 | d_Y_loss: 0.1085 | g_total_loss: 6.2082
# Epoch [ 2870/ 5000] | d_X_loss: 0.1537 | d_Y_loss: 0.1007 | g_total_loss: 4.2726
# Epoch [ 2880/ 5000] | d_X_loss: 0.4627 | d_Y_loss: 0.6100 | g_total_loss: 5.4746
# Epoch [ 2890/ 5000] | d_X_loss: 0.2519 | d_Y_loss: 0.6681 | g_total_loss: 4.3105
# Epoch [ 2900/ 5000] | d_X_loss: 0.7399 | d_Y_loss: 0.2557 | g_total_loss: 7.0274
# Epoch [ 2910/ 5000] | d_X_loss: 0.0586 | d_Y_loss: 0.3589 | g_total_loss: 6.6136
# Epoch [ 2920/ 5000] | d_X_loss: 3.1718 | d_Y_loss: 1.9600 | g_total_loss: 4.1583
# Epoch [ 2930/ 5000] | d_X_loss: 0.0760 | d_Y_loss: 0.2515 | g_total_loss: 3.5293
# Epoch [ 2940/ 5000] | d_X_loss: 0.2812 | d_Y_loss: 0.1699 | g_total_loss: 5.0161
# Epoch [ 2950/ 5000] | d_X_loss: 0.0656 | d_Y_loss: 0.4984 | g_total_loss: 3.4175
# Epoch [ 2960/ 5000] | d_X_loss: 0.1220 | d_Y_loss: 0.1270 | g_total_loss: 4.7766
# Epoch [ 2970/ 5000] | d_X_loss: 0.0824 | d_Y_loss: 0.1856 | g_total_loss: 3.2086
# Epoch [ 2980/ 5000] | d_X_loss: 0.0327 | d_Y_loss: 1.3816 | g_total_loss: 3.5546
# Epoch [ 2990/ 5000] | d_X_loss: 0.1981 | d_Y_loss: 0.5549 | g_total_loss: 4.0544
# Epoch [ 3000/ 5000] | d_X_loss: 0.6499 | d_Y_loss: 0.1168 | g_total_loss: 3.6548
# Epoch [ 3010/ 5000] | d_X_loss: 0.2572 | d_Y_loss: 0.2317 | g_total_loss: 3.9879
# Epoch [ 3020/ 5000] | d_X_loss: 1.1229 | d_Y_loss: 0.3856 | g_total_loss: 5.1479
# Epoch [ 3030/ 5000] | d_X_loss: 0.0549 | d_Y_loss: 1.1493 | g_total_loss: 2.9396
# Epoch [ 3040/ 5000] | d_X_loss: 0.1212 | d_Y_loss: 0.9169 | g_total_loss: 6.4255
# Epoch [ 3050/ 5000] | d_X_loss: 0.5121 | d_Y_loss: 0.9274 | g_total_loss: 4.2718
# Epoch [ 3060/ 5000] | d_X_loss: 1.9935 | d_Y_loss: 0.8115 | g_total_loss: 7.2434
# Epoch [ 3070/ 5000] | d_X_loss: 0.0776 | d_Y_loss: 0.4462 | g_total_loss: 3.9914
# Epoch [ 3080/ 5000] | d_X_loss: 0.0733 | d_Y_loss: 0.1869 | g_total_loss: 3.9084
# Epoch [ 3090/ 5000] | d_X_loss: 0.1673 | d_Y_loss: 0.1104 | g_total_loss: 3.8842
# Epoch [ 3100/ 5000] | d_X_loss: 3.0018 | d_Y_loss: 1.1471 | g_total_loss: 3.1415
# Epoch [ 3110/ 5000] | d_X_loss: 0.0948 | d_Y_loss: 0.1252 | g_total_loss: 4.2667
# Epoch [ 3120/ 5000] | d_X_loss: 1.2163 | d_Y_loss: 0.1842 | g_total_loss: 5.6710
# Epoch [ 3130/ 5000] | d_X_loss: 0.2197 | d_Y_loss: 0.1835 | g_total_loss: 4.6577
# Epoch [ 3140/ 5000] | d_X_loss: 0.2711 | d_Y_loss: 0.1372 | g_total_loss: 4.8011
# Epoch [ 3150/ 5000] | d_X_loss: 0.3707 | d_Y_loss: 0.1617 | g_total_loss: 3.9891
# Epoch [ 3160/ 5000] | d_X_loss: 3.5694 | d_Y_loss: 0.7132 | g_total_loss: 3.9320
# Epoch [ 3170/ 5000] | d_X_loss: 0.5329 | d_Y_loss: 0.3207 | g_total_loss: 3.2709
# Epoch [ 3180/ 5000] | d_X_loss: 0.4600 | d_Y_loss: 0.2094 | g_total_loss: 3.2168
# Epoch [ 3190/ 5000] | d_X_loss: 1.2711 | d_Y_loss: 0.4798 | g_total_loss: 2.2466
# Epoch [ 3200/ 5000] | d_X_loss: 0.3851 | d_Y_loss: 0.6477 | g_total_loss: 5.8692
# Epoch [ 3210/ 5000] | d_X_loss: 0.0954 | d_Y_loss: 0.4021 | g_total_loss: 4.5192
# Epoch [ 3220/ 5000] | d_X_loss: 0.1345 | d_Y_loss: 1.6976 | g_total_loss: 3.3452
# Epoch [ 3230/ 5000] | d_X_loss: 0.2109 | d_Y_loss: 0.1774 | g_total_loss: 3.7716
# Epoch [ 3240/ 5000] | d_X_loss: 0.1558 | d_Y_loss: 0.3387 | g_total_loss: 2.7634
# Epoch [ 3250/ 5000] | d_X_loss: 0.4430 | d_Y_loss: 0.4986 | g_total_loss: 2.6263
# Epoch [ 3260/ 5000] | d_X_loss: 0.2455 | d_Y_loss: 0.1814 | g_total_loss: 3.4768
# Epoch [ 3270/ 5000] | d_X_loss: 0.2257 | d_Y_loss: 0.2883 | g_total_loss: 3.3001
# Epoch [ 3280/ 5000] | d_X_loss: 0.1752 | d_Y_loss: 0.2078 | g_total_loss: 3.0539
# Epoch [ 3290/ 5000] | d_X_loss: 0.3660 | d_Y_loss: 1.8047 | g_total_loss: 3.3198
# Epoch [ 3300/ 5000] | d_X_loss: 2.6500 | d_Y_loss: 0.9268 | g_total_loss: 4.3665
# Epoch [ 3310/ 5000] | d_X_loss: 0.1693 | d_Y_loss: 0.2444 | g_total_loss: 2.6881
# Epoch [ 3320/ 5000] | d_X_loss: 0.1873 | d_Y_loss: 0.0350 | g_total_loss: 3.4119
# Epoch [ 3330/ 5000] | d_X_loss: 0.2449 | d_Y_loss: 0.6854 | g_total_loss: 3.7713
# Epoch [ 3340/ 5000] | d_X_loss: 0.5880 | d_Y_loss: 0.0996 | g_total_loss: 2.8705
# Epoch [ 3350/ 5000] | d_X_loss: 0.1764 | d_Y_loss: 0.3403 | g_total_loss: 3.1605
# Epoch [ 3360/ 5000] | d_X_loss: 3.7191 | d_Y_loss: 2.1369 | g_total_loss: 6.0482
# Epoch [ 3370/ 5000] | d_X_loss: 0.1438 | d_Y_loss: 0.3605 | g_total_loss: 2.5877
# Epoch [ 3380/ 5000] | d_X_loss: 0.6306 | d_Y_loss: 0.0506 | g_total_loss: 3.5735
# Epoch [ 3390/ 5000] | d_X_loss: 0.3772 | d_Y_loss: 0.3012 | g_total_loss: 2.7626
# Epoch [ 3400/ 5000] | d_X_loss: 1.0225 | d_Y_loss: 0.0411 | g_total_loss: 3.8539
# Epoch [ 3410/ 5000] | d_X_loss: 0.6037 | d_Y_loss: 0.2430 | g_total_loss: 2.2883
# Epoch [ 3420/ 5000] | d_X_loss: 0.8887 | d_Y_loss: 0.9768 | g_total_loss: 2.3454
# Epoch [ 3430/ 5000] | d_X_loss: 0.5542 | d_Y_loss: 0.2349 | g_total_loss: 3.1136
# Epoch [ 3440/ 5000] | d_X_loss: 0.3355 | d_Y_loss: 0.0854 | g_total_loss: 3.2262
# Epoch [ 3450/ 5000] | d_X_loss: 0.4932 | d_Y_loss: 0.2271 | g_total_loss: 2.3311
# Epoch [ 3460/ 5000] | d_X_loss: 0.1244 | d_Y_loss: 0.0521 | g_total_loss: 3.5297
# Epoch [ 3470/ 5000] | d_X_loss: 0.5324 | d_Y_loss: 0.2403 | g_total_loss: 2.9435
# Epoch [ 3480/ 5000] | d_X_loss: 1.9390 | d_Y_loss: 0.0946 | g_total_loss: 3.2134
# Epoch [ 3490/ 5000] | d_X_loss: 0.2953 | d_Y_loss: 0.9097 | g_total_loss: 4.3425
# Epoch [ 3500/ 5000] | d_X_loss: 50.7578 | d_Y_loss: 0.0534 | g_total_loss: 12.0115
# Epoch [ 3510/ 5000] | d_X_loss: 0.3751 | d_Y_loss: 0.2093 | g_total_loss: 3.9928
# Epoch [ 3520/ 5000] | d_X_loss: 0.2307 | d_Y_loss: 0.0770 | g_total_loss: 4.8157
# Epoch [ 3530/ 5000] | d_X_loss: 0.2112 | d_Y_loss: 0.1250 | g_total_loss: 4.4433
# Epoch [ 3540/ 5000] | d_X_loss: 0.1424 | d_Y_loss: 0.4005 | g_total_loss: 3.6416
# Epoch [ 3550/ 5000] | d_X_loss: 0.1185 | d_Y_loss: 0.1529 | g_total_loss: 4.7845
# Epoch [ 3560/ 5000] | d_X_loss: 0.1025 | d_Y_loss: 0.1254 | g_total_loss: 3.7110
# Epoch [ 3570/ 5000] | d_X_loss: 0.0972 | d_Y_loss: 0.2499 | g_total_loss: 3.1786
# Epoch [ 3580/ 5000] | d_X_loss: 0.1229 | d_Y_loss: 0.2688 | g_total_loss: 5.1649
# Epoch [ 3590/ 5000] | d_X_loss: 0.0926 | d_Y_loss: 0.3230 | g_total_loss: 4.3702
# Epoch [ 3600/ 5000] | d_X_loss: 0.1204 | d_Y_loss: 0.6473 | g_total_loss: 3.5737
# Epoch [ 3610/ 5000] | d_X_loss: 0.1076 | d_Y_loss: 0.1607 | g_total_loss: 3.4156
# Epoch [ 3620/ 5000] | d_X_loss: 0.3854 | d_Y_loss: 1.2147 | g_total_loss: 6.5641
# Epoch [ 3630/ 5000] | d_X_loss: 0.0826 | d_Y_loss: 0.1468 | g_total_loss: 3.8844
# Epoch [ 3640/ 5000] | d_X_loss: 0.3749 | d_Y_loss: 0.0862 | g_total_loss: 4.4856
# Epoch [ 3650/ 5000] | d_X_loss: 0.4538 | d_Y_loss: 0.6222 | g_total_loss: 5.2271
# Epoch [ 3660/ 5000] | d_X_loss: 0.0558 | d_Y_loss: 0.0529 | g_total_loss: 3.5665
# Epoch [ 3670/ 5000] | d_X_loss: 0.2679 | d_Y_loss: 0.1634 | g_total_loss: 4.1691
# Epoch [ 3680/ 5000] | d_X_loss: 0.1329 | d_Y_loss: 0.1481 | g_total_loss: 4.5952
# Epoch [ 3690/ 5000] | d_X_loss: 0.0947 | d_Y_loss: 0.6477 | g_total_loss: 4.3596
# Epoch [ 3700/ 5000] | d_X_loss: 0.0623 | d_Y_loss: 0.1742 | g_total_loss: 3.3601
# Epoch [ 3710/ 5000] | d_X_loss: 0.1340 | d_Y_loss: 0.1318 | g_total_loss: 3.7364
# Epoch [ 3720/ 5000] | d_X_loss: 0.0563 | d_Y_loss: 0.2055 | g_total_loss: 4.5492
# Epoch [ 3730/ 5000] | d_X_loss: 0.1374 | d_Y_loss: 0.1873 | g_total_loss: 3.2208
# Epoch [ 3740/ 5000] | d_X_loss: 0.2102 | d_Y_loss: 0.1570 | g_total_loss: 4.6249
# Epoch [ 3750/ 5000] | d_X_loss: 0.2315 | d_Y_loss: 0.9635 | g_total_loss: 4.6073
# Epoch [ 3760/ 5000] | d_X_loss: 0.0303 | d_Y_loss: 0.0680 | g_total_loss: 3.6773
# Epoch [ 3770/ 5000] | d_X_loss: 0.4904 | d_Y_loss: 0.2335 | g_total_loss: 3.2690
# Epoch [ 3780/ 5000] | d_X_loss: 0.1259 | d_Y_loss: 0.0605 | g_total_loss: 4.0315
# Epoch [ 3790/ 5000] | d_X_loss: 0.3347 | d_Y_loss: 0.4290 | g_total_loss: 3.2178
# Epoch [ 3800/ 5000] | d_X_loss: 3.5644 | d_Y_loss: 0.0890 | g_total_loss: 5.7962
# Epoch [ 3810/ 5000] | d_X_loss: 0.1151 | d_Y_loss: 0.4075 | g_total_loss: 3.9295
# Epoch [ 3820/ 5000] | d_X_loss: 0.1356 | d_Y_loss: 0.0435 | g_total_loss: 4.2120
# Epoch [ 3830/ 5000] | d_X_loss: 0.1474 | d_Y_loss: 0.6381 | g_total_loss: 4.3612
# Epoch [ 3840/ 5000] | d_X_loss: 0.2461 | d_Y_loss: 0.4105 | g_total_loss: 2.8566
# Epoch [ 3850/ 5000] | d_X_loss: 0.2575 | d_Y_loss: 0.1745 | g_total_loss: 3.8713
# Epoch [ 3860/ 5000] | d_X_loss: 0.3466 | d_Y_loss: 0.1793 | g_total_loss: 3.4218
# Epoch [ 3870/ 5000] | d_X_loss: 0.0671 | d_Y_loss: 0.2319 | g_total_loss: 3.3540
# Epoch [ 3880/ 5000] | d_X_loss: 0.4361 | d_Y_loss: 0.1485 | g_total_loss: 4.7633
# Epoch [ 3890/ 5000] | d_X_loss: 0.1868 | d_Y_loss: 0.1841 | g_total_loss: 3.3382
# Epoch [ 3900/ 5000] | d_X_loss: 0.3475 | d_Y_loss: 0.0417 | g_total_loss: 3.3007
# Epoch [ 3910/ 5000] | d_X_loss: 0.2558 | d_Y_loss: 0.1903 | g_total_loss: 3.6520
# Epoch [ 3920/ 5000] | d_X_loss: 0.0580 | d_Y_loss: 0.1645 | g_total_loss: 3.2411
# Epoch [ 3930/ 5000] | d_X_loss: 0.0779 | d_Y_loss: 0.5238 | g_total_loss: 5.1189
# Epoch [ 3940/ 5000] | d_X_loss: 0.0999 | d_Y_loss: 0.1215 | g_total_loss: 3.7556
# Epoch [ 3950/ 5000] | d_X_loss: 0.2072 | d_Y_loss: 0.2508 | g_total_loss: 2.8141
# Epoch [ 3960/ 5000] | d_X_loss: 0.3090 | d_Y_loss: 0.0628 | g_total_loss: 4.0151
# Epoch [ 3970/ 5000] | d_X_loss: 0.3335 | d_Y_loss: 0.1946 | g_total_loss: 4.7070
# Epoch [ 3980/ 5000] | d_X_loss: 0.1672 | d_Y_loss: 0.0320 | g_total_loss: 3.8670
# Epoch [ 3990/ 5000] | d_X_loss: 0.2420 | d_Y_loss: 0.1933 | g_total_loss: 2.8400
# Epoch [ 4000/ 5000] | d_X_loss: 0.1494 | d_Y_loss: 0.1823 | g_total_loss: 3.3770
# Epoch [ 4010/ 5000] | d_X_loss: 0.0665 | d_Y_loss: 1.4815 | g_total_loss: 4.2876
# Epoch [ 4020/ 5000] | d_X_loss: 0.0937 | d_Y_loss: 0.0787 | g_total_loss: 3.4848
# Epoch [ 4030/ 5000] | d_X_loss: 0.1694 | d_Y_loss: 0.2896 | g_total_loss: 3.1715
# Epoch [ 4040/ 5000] | d_X_loss: 0.3047 | d_Y_loss: 0.0347 | g_total_loss: 3.4937
# Epoch [ 4050/ 5000] | d_X_loss: 0.1275 | d_Y_loss: 0.2744 | g_total_loss: 3.2243
# Epoch [ 4060/ 5000] | d_X_loss: 0.1678 | d_Y_loss: 0.0454 | g_total_loss: 3.4678
# Epoch [ 4070/ 5000] | d_X_loss: 0.0862 | d_Y_loss: 0.2104 | g_total_loss: 3.2468
# Epoch [ 4080/ 5000] | d_X_loss: 0.1771 | d_Y_loss: 1.9567 | g_total_loss: 5.4014
# Epoch [ 4090/ 5000] | d_X_loss: 0.2932 | d_Y_loss: 0.3273 | g_total_loss: 2.9461
# Epoch [ 4100/ 5000] | d_X_loss: 0.1633 | d_Y_loss: 0.0275 | g_total_loss: 3.4141
# Epoch [ 4110/ 5000] | d_X_loss: 0.3318 | d_Y_loss: 0.2173 | g_total_loss: 3.1391
# Epoch [ 4120/ 5000] | d_X_loss: 0.2646 | d_Y_loss: 0.0268 | g_total_loss: 3.8435
# Epoch [ 4130/ 5000] | d_X_loss: 0.2774 | d_Y_loss: 0.1757 | g_total_loss: 3.3450
# Epoch [ 4140/ 5000] | d_X_loss: 0.9991 | d_Y_loss: 0.0406 | g_total_loss: 5.1865
# Epoch [ 4150/ 5000] | d_X_loss: 0.1088 | d_Y_loss: 0.2383 | g_total_loss: 3.6096
# Epoch [ 4160/ 5000] | d_X_loss: 0.0716 | d_Y_loss: 0.1030 | g_total_loss: 3.3039
# Epoch [ 4170/ 5000] | d_X_loss: 0.0439 | d_Y_loss: 0.3658 | g_total_loss: 3.9294
# Epoch [ 4180/ 5000] | d_X_loss: 0.0838 | d_Y_loss: 0.0545 | g_total_loss: 3.2912
# Epoch [ 4190/ 5000] | d_X_loss: 0.0551 | d_Y_loss: 0.2036 | g_total_loss: 3.1950
# Epoch [ 4200/ 5000] | d_X_loss: 0.5079 | d_Y_loss: 0.0352 | g_total_loss: 4.2472
# Epoch [ 4210/ 5000] | d_X_loss: 0.1159 | d_Y_loss: 0.2030 | g_total_loss: 2.6552
# Epoch [ 4220/ 5000] | d_X_loss: 0.5366 | d_Y_loss: 0.1723 | g_total_loss: 4.3582
# Epoch [ 4230/ 5000] | d_X_loss: 0.1693 | d_Y_loss: 0.2648 | g_total_loss: 2.9588
# Epoch [ 4240/ 5000] | d_X_loss: 0.9719 | d_Y_loss: 0.0457 | g_total_loss: 4.1540
# Epoch [ 4250/ 5000] | d_X_loss: 0.1228 | d_Y_loss: 0.1751 | g_total_loss: 3.0203
# Epoch [ 4260/ 5000] | d_X_loss: 0.1649 | d_Y_loss: 0.0439 | g_total_loss: 3.1994
# Epoch [ 4270/ 5000] | d_X_loss: 0.2176 | d_Y_loss: 0.2477 | g_total_loss: 3.0277
# Epoch [ 4280/ 5000] | d_X_loss: 0.1881 | d_Y_loss: 0.0559 | g_total_loss: 3.2600
# Epoch [ 4290/ 5000] | d_X_loss: 0.1981 | d_Y_loss: 0.2051 | g_total_loss: 3.3088
# Epoch [ 4300/ 5000] | d_X_loss: 0.1231 | d_Y_loss: 0.0720 | g_total_loss: 3.1485
# Epoch [ 4310/ 5000] | d_X_loss: 0.1663 | d_Y_loss: 0.3641 | g_total_loss: 2.3640
# Epoch [ 4320/ 5000] | d_X_loss: 1.6532 | d_Y_loss: 0.0513 | g_total_loss: 5.2715
# Epoch [ 4330/ 5000] | d_X_loss: 0.1239 | d_Y_loss: 0.1556 | g_total_loss: 2.4283
# Epoch [ 4340/ 5000] | d_X_loss: 0.1220 | d_Y_loss: 0.0210 | g_total_loss: 3.3160
# Epoch [ 4350/ 5000] | d_X_loss: 0.1414 | d_Y_loss: 0.1048 | g_total_loss: 2.6985
# Epoch [ 4360/ 5000] | d_X_loss: 0.1076 | d_Y_loss: 0.0557 | g_total_loss: 3.8312
# Epoch [ 4370/ 5000] | d_X_loss: 0.1714 | d_Y_loss: 0.1900 | g_total_loss: 2.9079
# Epoch [ 4380/ 5000] | d_X_loss: 0.2913 | d_Y_loss: 0.0456 | g_total_loss: 3.2932
# Epoch [ 4390/ 5000] | d_X_loss: 0.1700 | d_Y_loss: 0.1255 | g_total_loss: 3.0082
# Epoch [ 4400/ 5000] | d_X_loss: 0.1864 | d_Y_loss: 0.0427 | g_total_loss: 3.0720
# Epoch [ 4410/ 5000] | d_X_loss: 0.5446 | d_Y_loss: 0.1016 | g_total_loss: 4.3433
# Epoch [ 4420/ 5000] | d_X_loss: 0.7226 | d_Y_loss: 0.0657 | g_total_loss: 3.5450
# Epoch [ 4430/ 5000] | d_X_loss: 0.1357 | d_Y_loss: 0.1223 | g_total_loss: 3.1806
# Epoch [ 4440/ 5000] | d_X_loss: 0.8568 | d_Y_loss: 0.0724 | g_total_loss: 3.9955
# Epoch [ 4450/ 5000] | d_X_loss: 0.1673 | d_Y_loss: 0.1614 | g_total_loss: 2.9782
# Epoch [ 4460/ 5000] | d_X_loss: 0.5488 | d_Y_loss: 0.2805 | g_total_loss: 3.0702
# Epoch [ 4470/ 5000] | d_X_loss: 0.0729 | d_Y_loss: 0.0966 | g_total_loss: 3.1474
# Epoch [ 4480/ 5000] | d_X_loss: 0.4603 | d_Y_loss: 0.0406 | g_total_loss: 3.4985
# Epoch [ 4490/ 5000] | d_X_loss: 0.0936 | d_Y_loss: 0.0844 | g_total_loss: 2.8351
# Epoch [ 4500/ 5000] | d_X_loss: 0.4221 | d_Y_loss: 0.1695 | g_total_loss: 3.6050
# Epoch [ 4510/ 5000] | d_X_loss: 0.1002 | d_Y_loss: 0.1134 | g_total_loss: 2.9209
# Epoch [ 4520/ 5000] | d_X_loss: 0.2901 | d_Y_loss: 0.0691 | g_total_loss: 3.5237
# Epoch [ 4530/ 5000] | d_X_loss: 0.0556 | d_Y_loss: 0.1018 | g_total_loss: 2.7812
# Epoch [ 4540/ 5000] | d_X_loss: 0.1811 | d_Y_loss: 0.0586 | g_total_loss: 3.3861
# Epoch [ 4550/ 5000] | d_X_loss: 0.0689 | d_Y_loss: 0.1027 | g_total_loss: 3.1079
# Epoch [ 4560/ 5000] | d_X_loss: 0.2043 | d_Y_loss: 0.0422 | g_total_loss: 3.2366
# Epoch [ 4570/ 5000] | d_X_loss: 0.0716 | d_Y_loss: 0.0996 | g_total_loss: 2.8241
# Epoch [ 4580/ 5000] | d_X_loss: 0.2820 | d_Y_loss: 0.0339 | g_total_loss: 3.1680
# Epoch [ 4590/ 5000] | d_X_loss: 0.1044 | d_Y_loss: 0.0885 | g_total_loss: 2.7570
# Epoch [ 4600/ 5000] | d_X_loss: 0.1586 | d_Y_loss: 0.0322 | g_total_loss: 3.3827
# Epoch [ 4610/ 5000] | d_X_loss: 0.0516 | d_Y_loss: 0.0869 | g_total_loss: 2.7655
# Epoch [ 4620/ 5000] | d_X_loss: 0.0875 | d_Y_loss: 0.0341 | g_total_loss: 3.1801
# Epoch [ 4630/ 5000] | d_X_loss: 0.0811 | d_Y_loss: 0.0841 | g_total_loss: 2.7271
# Epoch [ 4640/ 5000] | d_X_loss: 0.0671 | d_Y_loss: 0.0274 | g_total_loss: 3.2155
# Epoch [ 4650/ 5000] | d_X_loss: 0.0717 | d_Y_loss: 0.0823 | g_total_loss: 2.7693
# Epoch [ 4660/ 5000] | d_X_loss: 0.0742 | d_Y_loss: 0.0280 | g_total_loss: 3.2563
# Epoch [ 4670/ 5000] | d_X_loss: 0.0570 | d_Y_loss: 0.0857 | g_total_loss: 2.6693
# Epoch [ 4680/ 5000] | d_X_loss: 0.0649 | d_Y_loss: 0.0231 | g_total_loss: 3.3143
# Epoch [ 4690/ 5000] | d_X_loss: 0.5964 | d_Y_loss: 0.0754 | g_total_loss: 3.3662
# Epoch [ 4700/ 5000] | d_X_loss: 0.1432 | d_Y_loss: 0.0241 | g_total_loss: 3.1967
# Epoch [ 4710/ 5000] | d_X_loss: 0.3600 | d_Y_loss: 0.0766 | g_total_loss: 2.9397
# Epoch [ 4720/ 5000] | d_X_loss: 0.2450 | d_Y_loss: 0.0222 | g_total_loss: 2.9453
# Epoch [ 4730/ 5000] | d_X_loss: 0.0718 | d_Y_loss: 0.0762 | g_total_loss: 3.0331
# Epoch [ 4740/ 5000] | d_X_loss: 0.1956 | d_Y_loss: 0.0246 | g_total_loss: 2.9614
# Epoch [ 4750/ 5000] | d_X_loss: 0.0648 | d_Y_loss: 0.0768 | g_total_loss: 2.7684
# Epoch [ 4760/ 5000] | d_X_loss: 0.2316 | d_Y_loss: 0.0246 | g_total_loss: 2.9623
# Epoch [ 4770/ 5000] | d_X_loss: 0.0599 | d_Y_loss: 0.0783 | g_total_loss: 2.8254
# Epoch [ 4780/ 5000] | d_X_loss: 0.1709 | d_Y_loss: 0.0235 | g_total_loss: 2.9503
# Epoch [ 4790/ 5000] | d_X_loss: 0.0586 | d_Y_loss: 0.0691 | g_total_loss: 2.7262
# Epoch [ 4800/ 5000] | d_X_loss: 0.1600 | d_Y_loss: 0.0242 | g_total_loss: 2.9415
# Epoch [ 4810/ 5000] | d_X_loss: 0.1232 | d_Y_loss: 0.0647 | g_total_loss: 2.7741
# Epoch [ 4820/ 5000] | d_X_loss: 0.1705 | d_Y_loss: 0.0246 | g_total_loss: 2.9504
# Epoch [ 4830/ 5000] | d_X_loss: 0.0721 | d_Y_loss: 0.0652 | g_total_loss: 2.7912
# Epoch [ 4840/ 5000] | d_X_loss: 0.1645 | d_Y_loss: 0.0246 | g_total_loss: 2.9869
# Epoch [ 4850/ 5000] | d_X_loss: 0.0722 | d_Y_loss: 0.0640 | g_total_loss: 2.7378
# Epoch [ 4860/ 5000] | d_X_loss: 0.1516 | d_Y_loss: 0.0229 | g_total_loss: 2.9531
# Epoch [ 4870/ 5000] | d_X_loss: 0.0931 | d_Y_loss: 0.0628 | g_total_loss: 2.7289
# Epoch [ 4880/ 5000] | d_X_loss: 0.1407 | d_Y_loss: 0.0218 | g_total_loss: 2.9437
# Epoch [ 4890/ 5000] | d_X_loss: 0.0814 | d_Y_loss: 0.0625 | g_total_loss: 2.7315
# Epoch [ 4900/ 5000] | d_X_loss: 0.1354 | d_Y_loss: 0.0213 | g_total_loss: 2.9608
# Epoch [ 4910/ 5000] | d_X_loss: 0.0801 | d_Y_loss: 0.0623 | g_total_loss: 2.7176
# Epoch [ 4920/ 5000] | d_X_loss: 0.1333 | d_Y_loss: 0.0211 | g_total_loss: 2.9577
# Epoch [ 4930/ 5000] | d_X_loss: 0.0783 | d_Y_loss: 0.0615 | g_total_loss: 2.7248
# Epoch [ 4940/ 5000] | d_X_loss: 0.1308 | d_Y_loss: 0.0210 | g_total_loss: 2.9472
# Epoch [ 4950/ 5000] | d_X_loss: 0.0728 | d_Y_loss: 0.0599 | g_total_loss: 2.7278
# Epoch [ 4960/ 5000] | d_X_loss: 0.1292 | d_Y_loss: 0.0212 | g_total_loss: 2.9438
# Epoch [ 4970/ 5000] | d_X_loss: 0.0688 | d_Y_loss: 0.0600 | g_total_loss: 2.7294
# Epoch [ 4980/ 5000] | d_X_loss: 0.1263 | d_Y_loss: 0.0211 | g_total_loss: 2.9504
# Epoch [ 4990/ 5000] | d_X_loss: 0.0674 | d_Y_loss: 0.0594 | g_total_loss: 2.7356
# Epoch [ 5000/ 5000] | d_X_loss: 0.1260 | d_Y_loss: 0.0212 | g_total_loss: 2.9473

# %%
#@markdown ### Training losses
fig, ax = plt.subplots(figsize=(12,8))
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator, RGB', alpha=0.5)
plt.plot(losses.T[1], label='Discriminator, Depth', alpha=0.5)
plt.plot(losses.T[2], label='Generators', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %%
def calculate_psnr():
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    
    images = iter(D)
    
    psnrs = []
    for i in range(64):
        images_RGB, images_Depth = next(images)
        images_RGB, images_Depth = scale(images_RGB), scale(images_Depth)

        images_RGB = images_RGB.to(device)
        images_Depth = images_Depth.to(device)

        fake_Depth = gen_A2B(images_RGB)
        fake_Depth = fake_Depth.detach().cpu().numpy()
        images_RGB = images_RGB.cpu().numpy()
        images_Depth = images_Depth.cpu().numpy()
    
        psnr = cv2.PSNR(images_Depth, fake_Depth)
        psnrs.append(psnr)
    return np.mean(psnrs)

# %%
print("PSNR of 64 samples:", calculate_psnr())
# Out:
# PSNR of 64 samples: 59.07356828468073
