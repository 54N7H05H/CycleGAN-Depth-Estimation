# %%
import torch
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt


from PIL import Image
from torchvision.transforms import transforms
from torch.utils.data import DataLoader, Dataset
from torch.autograd import Variable

import os
import cv2
import numpy as np
import random
import glob

import warnings
warnings.filterwarnings("ignore")

# %%
def real_mse_loss(D_out):
    return torch.mean((D_out-1)**2)

def fake_mse_loss(D_out):
    return torch.mean(D_out**2)

def cycle_consistency_loss(real_im, reconstructed_im, lambda_weight):
    reconstr_loss = torch.mean(torch.abs(real_im - reconstructed_im))
    return lambda_weight*reconstr_loss

class LambdaLR:
    def __init__(self, n_epochs, decay_start_epoch):
        assert ((n_epochs - decay_start_epoch) > 0), "Decay must start before the training session ends!"
        self.n_epochs = n_epochs
        self.decay_start_epoch = decay_start_epoch

    def step(self, epoch):
        return 1.0 - max(0, epoch - self.decay_start_epoch)/(self.n_epochs - self.decay_start_epoch)

def weights_init_normal(m):
    classname = m.__class__.__name__

    if classname.find('Conv') != -1:
        torch.nn.init.normal(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm2d') != -1:
        torch.nn.init.normal(m.weight.data, 1.0, 0.02)
        torch.nn.init.constant(m.bias.data, 0.0)

def scale(x, feature_range=(-1, 1)):
    min, max = feature_range
    x = x * (max - min) + min
    return x

def to_data(x):
    if torch.cuda.is_available():
        x = x.cpu()
    x = x.data.numpy()
    x = ((x +1)*255 / (2)).astype(np.uint8) # rescale to 0-255
    return x

def checkpoint(iteration, G_A2B, G_B2A, D_A, D_B, checkpoint_dir='checkpoints'):
    os.makedirs(checkpoint_dir, exist_ok=True)
    G_A2B_path = os.path.join(checkpoint_dir, 'gen_A2B.pkl')
    G_B2A_path = os.path.join(checkpoint_dir, 'gen_B2A.pkl')
    D_A_path = os.path.join(checkpoint_dir, 'disc_A.pkl')
    D_B_path = os.path.join(checkpoint_dir, 'disc_B.pkl')
    torch.save(G_A2B.state_dict(), G_A2B_path)
    torch.save(G_B2A.state_dict(), G_B2A_path)
    torch.save(D_A.state_dict(), D_A_path)
    torch.save(D_B.state_dict(), D_B_path)

# %%
DATASET_DIRECTORY = '/kaggle/input/monocular-depth-estimation/val/indoors'

dataset = {}
for subdir, dirs, files in os.walk(DATASET_DIRECTORY):
  for file in files:
    basename = os.path.basename(os.path.join(subdir, file))
    if basename[-3:] == "png":
      basename = basename[:-4]
      kind = "rgb"
    elif basename[-9:] == "depth.npy":
      basename = basename[:-10]
      kind = "depth"
    elif basename[-14:] == "depth_mask.npy":
      basename = basename[:-15]
      kind = "mask"
    else:
      continue

    if not basename in dataset:
      dataset[basename] = { "rgb": None, "depth": None, "mask": None }
    dataset[basename][kind] = os.path.join(subdir, file)

# %%
class DIODEDataset(Dataset):
    def __init__(self, img_size=256, batch_size = 16, num_workers=0):
        super(Dataset, self).__init__()
        self.batch_size = batch_size
        self.img_size = img_size
        self.num_workers = num_workers
        self.keys = list(dataset.keys())
        
    def __len__(self):
        return len(dataset)
    
    @staticmethod
    def normalize(img):
        return (img * 2) - 1
    
    @staticmethod
    def denormalize(img):
        return (img + 1) / 2

    def __getitem__(self, idx):
        name = self.keys[idx]
        
        rgb = Image.open(dataset[name]['rgb'])
        rgb = np.array(rgb)
        rgb = ((rgb - np.min(rgb)) / (np.max(rgb) - np.min(rgb)))
        rgb = rgb.astype(np.float32)
        
        depth = dataset[name]["depth"]
        depth = np.load(depth).squeeze()

        mask = dataset[name]["mask"]
        mask = np.load(mask)
        mask = mask > 0

        max_depth = min(300, np.percentile(depth, 99))
        depth = np.clip(depth, 0.1, max_depth)
        depth = np.log(depth, where=mask)
        depth = np.ma.masked_where(~mask, depth)
        depth = np.clip(depth, 0.1, np.log(max_depth))
        depth = np.expand_dims(depth, axis=2)
        depth = np.concatenate([depth] * 3, axis=2)
        depth = ((depth - np.min(depth)) / (np.max(depth) - np.min(depth)))
        depth = depth.astype(np.float32)
        
        rgb, depth = torch.from_numpy(rgb), torch.from_numpy(depth)
        rgb, depth = rgb.permute(2, 0, 1), depth.permute(2, 0, 1)
        rgb = transforms.Resize((256, 256))(rgb)
        depth = transforms.Resize((256, 256))(depth)
        
        return rgb, depth

# %%
class ResnetBlock(nn.Module):
    def __init__(self,input_features):
        super(ResnetBlock, self).__init__()
        Resnet_convolution = [
                              nn.ReflectionPad2d(1),
                              nn.Conv2d(input_features,input_features,3),
                              nn.InstanceNorm2d(input_features),
                              nn.LeakyReLU(negative_slope = 0.01),
                              nn.ReflectionPad2d(1),
                              nn.Conv2d(input_features, input_features,3),
                              nn.InstanceNorm2d(input_features)
                             ]
        self.Resnet_convolution = nn.Sequential(*Resnet_convolution)

    def forward(self, x):
        return x+self.Resnet_convolution(x)

# %%
class Generator(nn.Module):
    def __init__(self, input_channels, num_ResnetBlocks = 6):

        super(Generator,self).__init__()

        GeneratorArchitecture = [
            nn.ReflectionPad2d(3),
            nn.Conv2d(input_channels,64,7),
            nn.InstanceNorm2d(64),
            nn.LeakyReLU(negative_slope = 0.01, inplace = True)
        ]

        input_features = 64
        output_features = input_features*2

        for _ in range(2):
            GeneratorArchitecture += [
                nn.Conv2d(input_features, output_features,3,stride =2, padding =1),
                nn.InstanceNorm2d(output_features),
                nn.PReLU(init =0.25)
            ]

            input_features = output_features
            output_features = input_features*2

        for _ in range(num_ResnetBlocks):
            GeneratorArchitecture += [ ResnetBlock(input_features) ]

        output_features = input_features//2

        for _ in range(2):
            GeneratorArchitecture += [
                nn.ConvTranspose2d(input_features, output_features,3, stride =2, padding=1, output_padding =1),
                nn.InstanceNorm2d(output_features),
                nn.PReLU(init =0.25)
            ]
            input_features= output_features
            output_features = input_features//2


        GeneratorArchitecture += [
            nn.ReflectionPad2d(3),
            nn.Conv2d(input_features, input_channels,7),
            nn.Tanh()
        ]

        self.GeneratorArchitecture = nn.Sequential(*GeneratorArchitecture)

    def forward(self, x):
        return self.GeneratorArchitecture(x)

# %%
# @title
class Discriminator(nn.Module):

    def __init__(self, input_channels):
        super(Discriminator,self).__init__()

        DiscriminatorArchitecture = [
            nn.Conv2d(input_channels, 128, 4, stride =2, padding=1),
            nn.LeakyReLU(negative_slope = 0.01, inplace = True),
        ]
        DiscriminatorArchitecture += [
            nn.Conv2d(128, 256,4,stride=2, padding =1),
            nn.InstanceNorm2d (256),
            nn.LeakyReLU(negative_slope = 0.01, inplace = True)
        ]
        DiscriminatorArchitecture += [
            nn.Conv2d(256,512,3, padding =1),
            nn.InstanceNorm2d (256),
            nn.LeakyReLU(negative_slope = 0.01, inplace = True)
        ]
        DiscriminatorArchitecture += [  nn.Conv2d(512, 1, 4, padding =1) ]

        self.DiscriminatorArchitecture = nn.Sequential(*DiscriminatorArchitecture)


    def forward(self, x):
        x = self.DiscriminatorArchitecture(x)
        return x

# %%
class Model:
    def __init__(self, generator_channels=3, discriminator_channels=3, num_res_blocks=6):
        self.generator_channels = generator_channels
        self.discriminator_channels = discriminator_channels
        self.num_res_blocks = num_res_blocks

    def create_model(self):
        generatorNetwork_A2B = Generator(self.generator_channels, num_ResnetBlocks = self.num_res_blocks)
        generatorNetwork_B2A = Generator(self.generator_channels, num_ResnetBlocks = self.num_res_blocks)
        discriminatorNetwork_A = Discriminator(self.discriminator_channels)
        discriminatorNetwork_B = Discriminator(self.discriminator_channels)

        if torch.cuda.is_available():
            generatorNetwork_A2B.cuda()
            generatorNetwork_B2A.cuda()
            discriminatorNetwork_A.cuda()
            discriminatorNetwork_B.cuda()
            print("Network moved to GPU")
        else:
            print("Network moved to CPU as no GPU devices were identified")


        generatorNetwork_A2B.apply(weights_init_normal)
        generatorNetwork_B2A.apply(weights_init_normal)
        discriminatorNetwork_A.apply(weights_init_normal)
        discriminatorNetwork_B.apply(weights_init_normal)

        return generatorNetwork_A2B,generatorNetwork_B2A,discriminatorNetwork_A,discriminatorNetwork_B

# %%
#@markdown ### Hyper parameters
input_numChannels = 3
batch_size   = 8                         
num_epochs   = 5000
learningRate = 0.001                      
decay_epoch  = int(round(0.6*num_epochs)) 
image_size   = 128

# %%
D = DIODEDataset()

# %%
mod = Model()
gen_A2B,gen_B2A,disc_A,disc_B = mod.create_model()
# Out:
# Network moved to GPU

# %%
#@markdown ### Define Generator parameters
generator_params = list(gen_A2B.parameters())+ list(gen_B2A.parameters())

# %%
def gen_images():
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    
    images_RGB, images_Depth = next(iter(D))
    images_RGB, images_Depth = scale(images_RGB), scale(images_Depth)
    
    images_RGB = images_RGB.to(device)
    images_Depth = images_Depth.to(device)
    
    fake_Depth = gen_A2B(images_RGB)
    fake_Depth = fake_Depth.detach()
    
    plt.figure(figsize=(15, 15))
    display_list = [images_RGB.cpu().permute(1, 2, 0), images_Depth.cpu().permute(1, 2, 0), fake_Depth.cpu().permute(1, 2, 0)]
    
    for i in range(3):
       display_list[i] = display_list[i] * 0.5 + 0.5
    title = ['RGB Image', 'Depth Image', 'Predicted Image']


    plt.subplot(1, 3, 1)
    plt.title('RGB Image')
    plt.imshow(display_list[0])
    plt.axis('off')

    plt.subplot(1, 3, 2)
    plt.title('Depth (Real) Image')
    plt.imshow(display_list[1][:,:,0], cmap='plasma')
    plt.axis('off')

    plt.subplot(1, 3, 3)
    plt.title('Depth (Estimated) Image')
    plt.imshow(display_list[2][:,:,0], cmap='plasma')
    plt.axis('off')

    plt.show()

# %%
gen_images()

# %%
#@markdown ### Define Optimizers and Learning Rate Schedulers
optimizer_gen = optim.Adadelta(generator_params, learningRate)
optimizer_disc_A = torch.optim.Adadelta(disc_A.parameters(),learningRate)
optimizer_disc_B = torch.optim.Adadelta(disc_B.parameters(), learningRate)

learningRate_scheduler_gen = torch.optim.lr_scheduler.LambdaLR(optimizer_gen,lr_lambda = LambdaLR(num_epochs,decay_epoch).step)
learningRate_scheduler_disc_A = torch.optim.lr_scheduler.LambdaLR(optimizer_disc_A, lr_lambda = LambdaLR(num_epochs,decay_epoch).step)
learningRate_scheduler_disc_B = torch.optim.lr_scheduler.LambdaLR(optimizer_disc_B, lr_lambda = LambdaLR(num_epochs,decay_epoch).step)

# %%
#@markdown ### Define the training loop
def training_loop(dataloader, test_dataloader, n_epochs=1000):
    print_every = 10
    losses = []
    test_iter = iter(test_dataloader)
    fixed_RGB, fixed_Depth = next(test_iter)
    fixed_RGB = scale(fixed_RGB)
    fixed_Depth = scale(fixed_Depth)
    
    train_iter = iter(dataloader)
    batches_per_epoch = 4

    for epoch in range(1, n_epochs+1):
        if epoch % batches_per_epoch == 0:
            train_iter = iter(dataloader)

        images_RGB, images_Depth = next(train_iter)
        images_RGB = scale(images_RGB)
        images_Depth = scale(images_Depth)


        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        images_RGB = images_RGB.to(device)
        images_Depth = images_Depth.to(device)
#-------------------------------------Discriminator Training-----------------------------------------------------#

        # optimizers are initialized to zero so that they don't carry forward the errors form previous epochs. Basically to
        # to avoid any accumulation
        optimizer_disc_A.zero_grad()

        # Discriminator-A is initially checked for its performance with real image
        out_RGB = disc_A(images_RGB)
        disc_A_real_loss = real_mse_loss(out_RGB)

        # A fake image is generated by the generator to check the Discriminator's performance with fake image
        fake_RGB = gen_B2A(images_Depth)


        out_RGB = disc_A(fake_RGB)
        disc_A_fake_loss = fake_mse_loss(out_RGB)

        # Losses produced while the above operations are added which is the total loss of the Discriminator-A. It is backpropogated
        disc_A_loss = disc_A_real_loss + disc_A_fake_loss
        disc_A_loss.backward()
        optimizer_disc_A.step()

        # Same operations as mentioned above are now performed on Discriminator-B
        optimizer_disc_B.zero_grad()

        out_Depth = disc_B(images_Depth)
        disc_B_real_loss = real_mse_loss(out_Depth)

        fake_Depth = gen_A2B(images_RGB)

        out_Depth = disc_B(fake_Depth)
        disc_B_fake_loss = fake_mse_loss(out_Depth)


        disc_B_loss = disc_B_real_loss + disc_B_fake_loss
        disc_B_loss.backward()
        optimizer_disc_B.step()

#------------------------------------------Generator Training---------------------------------------------------#

        optimizer_gen.zero_grad()

        # An image is produced from the generator (in this case generator-B2A is being trained) is produced to check how well it can
        fake_RGB = gen_B2A(images_Depth)

        # The generated image is then fed to discrminator to check the fakeness and the MSE loss is received
        out_RGB = disc_A(fake_RGB)
        gen_B2A_loss = real_mse_loss(out_RGB)

        # To check the consistency, the generated image is fed to other generator(A2B in this case) and reconstructed image is received
        reconstructed_Depth = gen_A2B(fake_RGB)
        # Reconstruction loss is received by comparing two images as mentioned in step(4) of training generators
        reconstructed_Depth_loss = cycle_consistency_loss(images_Depth, reconstructed_Depth, lambda_weight=10)


        # Same operations are done, but this time to train gen_A2B
        fake_Depth = gen_A2B(images_RGB)


        out_Depth = disc_B(fake_Depth)
        gen_A2B_loss = real_mse_loss(out_Depth)


        reconstructed_RGB = gen_B2A(fake_Depth)
        reconstructed_RGB_loss = cycle_consistency_loss(images_RGB, reconstructed_RGB, lambda_weight=10)

        # Losses from both the generators are received and propogated backwards
        g_total_loss = gen_B2A_loss + gen_A2B_loss + reconstructed_Depth_loss + reconstructed_RGB_loss
        g_total_loss.backward()
        optimizer_gen.step()

        # Weight decay as mentioned earlier
        learningRate_scheduler_gen.step()
        learningRate_scheduler_disc_A.step()
        learningRate_scheduler_disc_B.step()



        if epoch % print_every == 0:

            losses.append((disc_A_loss.item(), disc_B_loss.item(), g_total_loss.item()))
            print('Epoch [{:5d}/{:5d}] | d_X_loss: {:6.4f} | d_Y_loss: {:6.4f} | g_total_loss: {:6.4f}'.format(
                    epoch, n_epochs, disc_A_loss.item(), disc_B_loss.item(), g_total_loss.item()))

        # A training sample is saved every given time to check the performance of our network
        sample_every=100

        if epoch % sample_every == 0:
            gen_B2A.eval()
            gen_A2B.eval()
            gen_B2A.train()
            gen_A2B.train()

        # Models are saved after every given number of epochs
        checkpoint_every=100
        # Save the model parameters
        if epoch % checkpoint_every == 0:
            checkpoint(epoch, gen_A2B, gen_B2A, disc_A, disc_B)

    return losses

# %%
losses = training_loop(D, D, n_epochs=num_epochs)
# Out:
# Epoch [   10/ 5000] | d_X_loss: 2.2514 | d_Y_loss: 2.1021 | g_total_loss: 14.9908
# Epoch [   20/ 5000] | d_X_loss: 1.9443 | d_Y_loss: 1.9468 | g_total_loss: 15.5523
# Epoch [   30/ 5000] | d_X_loss: 1.7416 | d_Y_loss: 1.3818 | g_total_loss: 13.5086
# Epoch [   40/ 5000] | d_X_loss: 1.5004 | d_Y_loss: 1.6337 | g_total_loss: 14.3017
# Epoch [   50/ 5000] | d_X_loss: 1.4646 | d_Y_loss: 1.0793 | g_total_loss: 12.4298
# Epoch [   60/ 5000] | d_X_loss: 1.2813 | d_Y_loss: 1.3141 | g_total_loss: 13.2682
# Epoch [   70/ 5000] | d_X_loss: 1.2553 | d_Y_loss: 0.7830 | g_total_loss: 11.9959
# Epoch [   80/ 5000] | d_X_loss: 1.1112 | d_Y_loss: 1.0808 | g_total_loss: 12.3590
# Epoch [   90/ 5000] | d_X_loss: 1.0728 | d_Y_loss: 0.6445 | g_total_loss: 11.1253
# Epoch [  100/ 5000] | d_X_loss: 0.9913 | d_Y_loss: 0.9188 | g_total_loss: 11.5790
# Epoch [  110/ 5000] | d_X_loss: 0.9771 | d_Y_loss: 0.6724 | g_total_loss: 9.9959
# Epoch [  120/ 5000] | d_X_loss: 1.0899 | d_Y_loss: 0.6740 | g_total_loss: 11.1194
# Epoch [  130/ 5000] | d_X_loss: 0.8630 | d_Y_loss: 0.5878 | g_total_loss: 9.3483
# Epoch [  140/ 5000] | d_X_loss: 0.8370 | d_Y_loss: 0.7097 | g_total_loss: 10.3237
# Epoch [  150/ 5000] | d_X_loss: 0.7678 | d_Y_loss: 0.5276 | g_total_loss: 8.7830
# Epoch [  160/ 5000] | d_X_loss: 0.7573 | d_Y_loss: 0.6282 | g_total_loss: 9.7436
# Epoch [  170/ 5000] | d_X_loss: 0.6803 | d_Y_loss: 0.3894 | g_total_loss: 8.7028
# Epoch [  180/ 5000] | d_X_loss: 0.8616 | d_Y_loss: 0.4681 | g_total_loss: 9.4853
# Epoch [  190/ 5000] | d_X_loss: 0.6170 | d_Y_loss: 0.3581 | g_total_loss: 8.2727
# Epoch [  200/ 5000] | d_X_loss: 0.7818 | d_Y_loss: 0.4215 | g_total_loss: 9.0199
# Epoch [  210/ 5000] | d_X_loss: 0.5540 | d_Y_loss: 0.3312 | g_total_loss: 7.8499
# Epoch [  220/ 5000] | d_X_loss: 0.5857 | d_Y_loss: 0.4712 | g_total_loss: 8.3433
# Epoch [  230/ 5000] | d_X_loss: 0.5159 | d_Y_loss: 0.3799 | g_total_loss: 7.1634
# Epoch [  240/ 5000] | d_X_loss: 0.5577 | d_Y_loss: 0.4458 | g_total_loss: 8.0453
# Epoch [  250/ 5000] | d_X_loss: 0.4669 | d_Y_loss: 0.2854 | g_total_loss: 7.1835
# Epoch [  260/ 5000] | d_X_loss: 0.5172 | d_Y_loss: 0.4123 | g_total_loss: 7.6775
# Epoch [  270/ 5000] | d_X_loss: 0.4389 | d_Y_loss: 0.3392 | g_total_loss: 6.6063
# Epoch [  280/ 5000] | d_X_loss: 0.5455 | d_Y_loss: 0.3116 | g_total_loss: 7.5051
# Epoch [  290/ 5000] | d_X_loss: 0.4000 | d_Y_loss: 0.3169 | g_total_loss: 6.3185
# Epoch [  300/ 5000] | d_X_loss: 0.4623 | d_Y_loss: 0.3774 | g_total_loss: 7.1143
# Epoch [  310/ 5000] | d_X_loss: 0.3770 | d_Y_loss: 0.3057 | g_total_loss: 6.1285
# Epoch [  320/ 5000] | d_X_loss: 0.4376 | d_Y_loss: 0.3557 | g_total_loss: 6.8256
# Epoch [  330/ 5000] | d_X_loss: 0.3458 | d_Y_loss: 0.2334 | g_total_loss: 6.0978
# Epoch [  340/ 5000] | d_X_loss: 0.4119 | d_Y_loss: 0.3406 | g_total_loss: 6.5456
# Epoch [  350/ 5000] | d_X_loss: 0.3232 | d_Y_loss: 0.2205 | g_total_loss: 5.8506
# Epoch [  360/ 5000] | d_X_loss: 0.3970 | d_Y_loss: 0.3226 | g_total_loss: 6.2990
# Epoch [  370/ 5000] | d_X_loss: 0.3034 | d_Y_loss: 0.2192 | g_total_loss: 5.6298
# Epoch [  380/ 5000] | d_X_loss: 0.4205 | d_Y_loss: 0.2504 | g_total_loss: 6.2684
# Epoch [  390/ 5000] | d_X_loss: 0.2894 | d_Y_loss: 0.2111 | g_total_loss: 5.4483
# Epoch [  400/ 5000] | d_X_loss: 0.3655 | d_Y_loss: 0.3001 | g_total_loss: 5.8694
# Epoch [  410/ 5000] | d_X_loss: 0.2758 | d_Y_loss: 0.1987 | g_total_loss: 5.2768
# Epoch [  420/ 5000] | d_X_loss: 0.3835 | d_Y_loss: 0.2285 | g_total_loss: 5.8942
# Epoch [  430/ 5000] | d_X_loss: 0.2646 | d_Y_loss: 0.1972 | g_total_loss: 5.1154
# Epoch [  440/ 5000] | d_X_loss: 0.3484 | d_Y_loss: 0.2819 | g_total_loss: 5.5178
# Epoch [  450/ 5000] | d_X_loss: 0.2557 | d_Y_loss: 0.1881 | g_total_loss: 4.9723
# Epoch [  460/ 5000] | d_X_loss: 0.3564 | d_Y_loss: 0.2135 | g_total_loss: 5.5627
# Epoch [  470/ 5000] | d_X_loss: 0.2538 | d_Y_loss: 0.2325 | g_total_loss: 4.8838
# Epoch [  480/ 5000] | d_X_loss: 0.3324 | d_Y_loss: 0.2655 | g_total_loss: 5.1840
# Epoch [  490/ 5000] | d_X_loss: 0.2443 | d_Y_loss: 0.1764 | g_total_loss: 4.7181
# Epoch [  500/ 5000] | d_X_loss: 0.3330 | d_Y_loss: 0.2034 | g_total_loss: 5.2323
# Epoch [  510/ 5000] | d_X_loss: 0.2448 | d_Y_loss: 0.1705 | g_total_loss: 4.6125
# Epoch [  520/ 5000] | d_X_loss: 0.3175 | d_Y_loss: 0.1943 | g_total_loss: 5.0769
# Epoch [  530/ 5000] | d_X_loss: 0.2479 | d_Y_loss: 0.2239 | g_total_loss: 4.6445
# Epoch [  540/ 5000] | d_X_loss: 0.3315 | d_Y_loss: 0.2560 | g_total_loss: 4.7570
# Epoch [  550/ 5000] | d_X_loss: 0.2460 | d_Y_loss: 0.1694 | g_total_loss: 4.3702
# Epoch [  560/ 5000] | d_X_loss: 0.3333 | d_Y_loss: 0.2437 | g_total_loss: 4.5993
# Epoch [  570/ 5000] | d_X_loss: 0.2500 | d_Y_loss: 0.1646 | g_total_loss: 4.2666
# Epoch [  580/ 5000] | d_X_loss: 0.3295 | d_Y_loss: 0.2466 | g_total_loss: 4.4748
# Epoch [  590/ 5000] | d_X_loss: 0.2519 | d_Y_loss: 0.2154 | g_total_loss: 4.3377
# Epoch [  600/ 5000] | d_X_loss: 0.3316 | d_Y_loss: 0.2423 | g_total_loss: 4.3561
# Epoch [  610/ 5000] | d_X_loss: 0.2577 | d_Y_loss: 0.1603 | g_total_loss: 4.0517
# Epoch [  620/ 5000] | d_X_loss: 0.3136 | d_Y_loss: 0.1806 | g_total_loss: 4.4873
# Epoch [  630/ 5000] | d_X_loss: 0.2589 | d_Y_loss: 0.1589 | g_total_loss: 3.9424
# Epoch [  640/ 5000] | d_X_loss: 0.3139 | d_Y_loss: 0.1822 | g_total_loss: 4.3726
# Epoch [  650/ 5000] | d_X_loss: 0.2684 | d_Y_loss: 0.2216 | g_total_loss: 4.1490
# Epoch [  660/ 5000] | d_X_loss: 0.3425 | d_Y_loss: 0.2397 | g_total_loss: 4.0051
# Epoch [  670/ 5000] | d_X_loss: 0.2761 | d_Y_loss: 0.1712 | g_total_loss: 3.7850
# Epoch [  680/ 5000] | d_X_loss: 0.3328 | d_Y_loss: 0.2463 | g_total_loss: 3.8932
# Epoch [  690/ 5000] | d_X_loss: 0.2752 | d_Y_loss: 0.1681 | g_total_loss: 3.6972
# Epoch [  700/ 5000] | d_X_loss: 0.3402 | d_Y_loss: 0.2523 | g_total_loss: 3.7937
# Epoch [  710/ 5000] | d_X_loss: 0.2827 | d_Y_loss: 0.1640 | g_total_loss: 3.6090
# Epoch [  720/ 5000] | d_X_loss: 0.3093 | d_Y_loss: 0.1866 | g_total_loss: 4.0246
# Epoch [  730/ 5000] | d_X_loss: 0.2801 | d_Y_loss: 0.1723 | g_total_loss: 3.5491
# Epoch [  740/ 5000] | d_X_loss: 0.3433 | d_Y_loss: 0.2623 | g_total_loss: 3.6477
# Epoch [  750/ 5000] | d_X_loss: 0.2795 | d_Y_loss: 0.2478 | g_total_loss: 3.8214
# Epoch [  760/ 5000] | d_X_loss: 0.3405 | d_Y_loss: 0.2768 | g_total_loss: 3.5789
# Epoch [  770/ 5000] | d_X_loss: 0.2915 | d_Y_loss: 0.2033 | g_total_loss: 3.4455
# Epoch [  780/ 5000] | d_X_loss: 0.3148 | d_Y_loss: 0.1947 | g_total_loss: 3.8524
# Epoch [  790/ 5000] | d_X_loss: 0.2968 | d_Y_loss: 0.1871 | g_total_loss: 3.3406
# Epoch [  800/ 5000] | d_X_loss: 0.3435 | d_Y_loss: 0.3038 | g_total_loss: 3.4910
# Epoch [  810/ 5000] | d_X_loss: 0.2876 | d_Y_loss: 0.3044 | g_total_loss: 3.6537
# Epoch [  820/ 5000] | d_X_loss: 0.3500 | d_Y_loss: 0.3105 | g_total_loss: 3.4420
# Epoch [  830/ 5000] | d_X_loss: 0.3179 | d_Y_loss: 0.2069 | g_total_loss: 3.2531
# Epoch [  840/ 5000] | d_X_loss: 0.3548 | d_Y_loss: 0.3282 | g_total_loss: 3.4321
# Epoch [  850/ 5000] | d_X_loss: 0.3031 | d_Y_loss: 0.3305 | g_total_loss: 3.4526
# Epoch [  860/ 5000] | d_X_loss: 0.3592 | d_Y_loss: 0.3417 | g_total_loss: 3.4120
# Epoch [  870/ 5000] | d_X_loss: 0.3397 | d_Y_loss: 0.2331 | g_total_loss: 3.0879
# Epoch [  880/ 5000] | d_X_loss: 0.3316 | d_Y_loss: 0.2355 | g_total_loss: 3.6828
# Epoch [  890/ 5000] | d_X_loss: 0.3257 | d_Y_loss: 0.3762 | g_total_loss: 3.3197
# Epoch [  900/ 5000] | d_X_loss: 0.3400 | d_Y_loss: 0.2420 | g_total_loss: 3.6705
# Epoch [  910/ 5000] | d_X_loss: 0.3786 | d_Y_loss: 0.2719 | g_total_loss: 2.9852
# Epoch [  920/ 5000] | d_X_loss: 0.3909 | d_Y_loss: 0.3954 | g_total_loss: 3.3279
# Epoch [  930/ 5000] | d_X_loss: 0.4027 | d_Y_loss: 0.3073 | g_total_loss: 2.9402
# Epoch [  940/ 5000] | d_X_loss: 0.4145 | d_Y_loss: 0.4222 | g_total_loss: 3.3450
# Epoch [  950/ 5000] | d_X_loss: 0.3795 | d_Y_loss: 0.4349 | g_total_loss: 3.1512
# Epoch [  960/ 5000] | d_X_loss: 0.3925 | d_Y_loss: 0.2763 | g_total_loss: 3.6031
# Epoch [  970/ 5000] | d_X_loss: 0.3876 | d_Y_loss: 0.4523 | g_total_loss: 3.0346
# Epoch [  980/ 5000] | d_X_loss: 0.3871 | d_Y_loss: 0.2917 | g_total_loss: 3.5652
# Epoch [  990/ 5000] | d_X_loss: 0.4603 | d_Y_loss: 0.3482 | g_total_loss: 2.8397
# Epoch [ 1000/ 5000] | d_X_loss: 0.4540 | d_Y_loss: 0.4722 | g_total_loss: 3.1804
# Epoch [ 1010/ 5000] | d_X_loss: 0.4757 | d_Y_loss: 0.3578 | g_total_loss: 2.7156
# Epoch [ 1020/ 5000] | d_X_loss: 0.4089 | d_Y_loss: 0.3266 | g_total_loss: 3.4720
# Epoch [ 1030/ 5000] | d_X_loss: 0.4837 | d_Y_loss: 0.3616 | g_total_loss: 2.6728
# Epoch [ 1040/ 5000] | d_X_loss: 0.4017 | d_Y_loss: 0.3383 | g_total_loss: 3.4147
# Epoch [ 1050/ 5000] | d_X_loss: 0.4840 | d_Y_loss: 0.3999 | g_total_loss: 2.7309
# Epoch [ 1060/ 5000] | d_X_loss: 0.4860 | d_Y_loss: 0.4982 | g_total_loss: 3.0975
# Epoch [ 1070/ 5000] | d_X_loss: 0.4256 | d_Y_loss: 0.4894 | g_total_loss: 2.9903
# Epoch [ 1080/ 5000] | d_X_loss: 0.3921 | d_Y_loss: 0.3430 | g_total_loss: 3.2649
# Epoch [ 1090/ 5000] | d_X_loss: 0.5025 | d_Y_loss: 0.3712 | g_total_loss: 2.6135
# Epoch [ 1100/ 5000] | d_X_loss: 0.4722 | d_Y_loss: 0.4990 | g_total_loss: 3.0258
# Epoch [ 1110/ 5000] | d_X_loss: 0.4214 | d_Y_loss: 0.4850 | g_total_loss: 2.9129
# Epoch [ 1120/ 5000] | d_X_loss: 0.4754 | d_Y_loss: 0.4900 | g_total_loss: 3.0431
# Epoch [ 1130/ 5000] | d_X_loss: 0.5106 | d_Y_loss: 0.4096 | g_total_loss: 2.6212
# Epoch [ 1140/ 5000] | d_X_loss: 0.4774 | d_Y_loss: 0.4771 | g_total_loss: 2.9862
# Epoch [ 1150/ 5000] | d_X_loss: 0.5176 | d_Y_loss: 0.3756 | g_total_loss: 2.5705
# Epoch [ 1160/ 5000] | d_X_loss: 0.4838 | d_Y_loss: 0.4756 | g_total_loss: 2.9318
# Epoch [ 1170/ 5000] | d_X_loss: 0.5152 | d_Y_loss: 0.3792 | g_total_loss: 2.5617
# Epoch [ 1180/ 5000] | d_X_loss: 0.3976 | d_Y_loss: 0.3574 | g_total_loss: 3.2372
# Epoch [ 1190/ 5000] | d_X_loss: 0.4147 | d_Y_loss: 0.4506 | g_total_loss: 2.8146
# Epoch [ 1200/ 5000] | d_X_loss: 0.3751 | d_Y_loss: 0.3557 | g_total_loss: 3.2312
# Epoch [ 1210/ 5000] | d_X_loss: 0.5195 | d_Y_loss: 0.3854 | g_total_loss: 2.5455
# Epoch [ 1220/ 5000] | d_X_loss: 0.3866 | d_Y_loss: 0.3514 | g_total_loss: 3.1627
# Epoch [ 1230/ 5000] | d_X_loss: 0.4050 | d_Y_loss: 0.4388 | g_total_loss: 2.8236
# Epoch [ 1240/ 5000] | d_X_loss: 0.4723 | d_Y_loss: 0.4499 | g_total_loss: 2.8824
# Epoch [ 1250/ 5000] | d_X_loss: 0.4989 | d_Y_loss: 0.3665 | g_total_loss: 2.5155
# Epoch [ 1260/ 5000] | d_X_loss: 0.4753 | d_Y_loss: 0.4407 | g_total_loss: 2.8894
# Epoch [ 1270/ 5000] | d_X_loss: 0.3927 | d_Y_loss: 0.4289 | g_total_loss: 2.7991
# Epoch [ 1280/ 5000] | d_X_loss: 0.4716 | d_Y_loss: 0.4375 | g_total_loss: 2.9411
# Epoch [ 1290/ 5000] | d_X_loss: 0.4716 | d_Y_loss: 0.3870 | g_total_loss: 2.5390
# Epoch [ 1300/ 5000] | d_X_loss: 0.3710 | d_Y_loss: 0.3529 | g_total_loss: 3.1593
# Epoch [ 1310/ 5000] | d_X_loss: 0.4684 | d_Y_loss: 0.3668 | g_total_loss: 2.4778
# Epoch [ 1320/ 5000] | d_X_loss: 0.4618 | d_Y_loss: 0.4199 | g_total_loss: 2.8392
# Epoch [ 1330/ 5000] | d_X_loss: 0.4607 | d_Y_loss: 0.3614 | g_total_loss: 2.4962
# Epoch [ 1340/ 5000] | d_X_loss: 0.4580 | d_Y_loss: 0.4080 | g_total_loss: 2.8291
# Epoch [ 1350/ 5000] | d_X_loss: 0.4517 | d_Y_loss: 0.3580 | g_total_loss: 2.4790
# Epoch [ 1360/ 5000] | d_X_loss: 0.4696 | d_Y_loss: 0.3995 | g_total_loss: 2.9091
# Epoch [ 1370/ 5000] | d_X_loss: 0.4337 | d_Y_loss: 0.3799 | g_total_loss: 2.5663
# Epoch [ 1380/ 5000] | d_X_loss: 0.4549 | d_Y_loss: 0.3919 | g_total_loss: 2.8294
# Epoch [ 1390/ 5000] | d_X_loss: 0.3698 | d_Y_loss: 0.4031 | g_total_loss: 2.8440
# Epoch [ 1400/ 5000] | d_X_loss: 0.4569 | d_Y_loss: 0.3751 | g_total_loss: 2.7886
# Epoch [ 1410/ 5000] | d_X_loss: 0.4308 | d_Y_loss: 0.3619 | g_total_loss: 2.4754
# Epoch [ 1420/ 5000] | d_X_loss: 0.4474 | d_Y_loss: 0.3709 | g_total_loss: 2.7921
# Epoch [ 1430/ 5000] | d_X_loss: 0.3444 | d_Y_loss: 0.3958 | g_total_loss: 2.7550
# Epoch [ 1440/ 5000] | d_X_loss: 0.4417 | d_Y_loss: 0.3677 | g_total_loss: 2.8148
# Epoch [ 1450/ 5000] | d_X_loss: 0.4122 | d_Y_loss: 0.3786 | g_total_loss: 2.4987
# Epoch [ 1460/ 5000] | d_X_loss: 0.4393 | d_Y_loss: 0.3624 | g_total_loss: 2.7948
# Epoch [ 1470/ 5000] | d_X_loss: 0.3396 | d_Y_loss: 0.3947 | g_total_loss: 2.7908
# Epoch [ 1480/ 5000] | d_X_loss: 0.3264 | d_Y_loss: 0.3347 | g_total_loss: 3.0273
# Epoch [ 1490/ 5000] | d_X_loss: 0.3990 | d_Y_loss: 0.3697 | g_total_loss: 2.4225
# Epoch [ 1500/ 5000] | d_X_loss: 0.3217 | d_Y_loss: 0.3303 | g_total_loss: 2.9987
# Epoch [ 1510/ 5000] | d_X_loss: 0.3189 | d_Y_loss: 0.3865 | g_total_loss: 2.7233
# Epoch [ 1520/ 5000] | d_X_loss: 0.4401 | d_Y_loss: 0.3574 | g_total_loss: 2.7743
# Epoch [ 1530/ 5000] | d_X_loss: 0.3865 | d_Y_loss: 0.3840 | g_total_loss: 2.4405
# Epoch [ 1540/ 5000] | d_X_loss: 0.4334 | d_Y_loss: 0.3511 | g_total_loss: 2.7480
# Epoch [ 1550/ 5000] | d_X_loss: 0.3843 | d_Y_loss: 0.3718 | g_total_loss: 2.4068
# Epoch [ 1560/ 5000] | d_X_loss: 0.4298 | d_Y_loss: 0.3460 | g_total_loss: 2.6983
# Epoch [ 1570/ 5000] | d_X_loss: 0.3722 | d_Y_loss: 0.3621 | g_total_loss: 2.4694
# Epoch [ 1580/ 5000] | d_X_loss: 0.4148 | d_Y_loss: 0.3375 | g_total_loss: 2.7053
# Epoch [ 1590/ 5000] | d_X_loss: 0.3753 | d_Y_loss: 0.3625 | g_total_loss: 2.4121
# Epoch [ 1600/ 5000] | d_X_loss: 0.3059 | d_Y_loss: 0.3294 | g_total_loss: 3.0774
# Epoch [ 1610/ 5000] | d_X_loss: 0.3037 | d_Y_loss: 0.3938 | g_total_loss: 2.7093
# Epoch [ 1620/ 5000] | d_X_loss: 0.4163 | d_Y_loss: 0.3356 | g_total_loss: 2.6836
# Epoch [ 1630/ 5000] | d_X_loss: 0.3025 | d_Y_loss: 0.3754 | g_total_loss: 2.7269
# Epoch [ 1640/ 5000] | d_X_loss: 0.3031 | d_Y_loss: 0.3299 | g_total_loss: 2.8910
# Epoch [ 1650/ 5000] | d_X_loss: 0.3044 | d_Y_loss: 0.3847 | g_total_loss: 2.6868
# Epoch [ 1660/ 5000] | d_X_loss: 0.4220 | d_Y_loss: 0.3299 | g_total_loss: 2.7135
# Epoch [ 1670/ 5000] | d_X_loss: 0.3614 | d_Y_loss: 0.3632 | g_total_loss: 2.3872
# Epoch [ 1680/ 5000] | d_X_loss: 0.4217 | d_Y_loss: 0.3274 | g_total_loss: 2.7622
# Epoch [ 1690/ 5000] | d_X_loss: 0.3611 | d_Y_loss: 0.3721 | g_total_loss: 2.4406
# Epoch [ 1700/ 5000] | d_X_loss: 0.4113 | d_Y_loss: 0.3315 | g_total_loss: 2.6780
# Epoch [ 1710/ 5000] | d_X_loss: 0.2954 | d_Y_loss: 0.3640 | g_total_loss: 2.6499
# Epoch [ 1720/ 5000] | d_X_loss: 0.3008 | d_Y_loss: 0.3335 | g_total_loss: 2.8479
# Epoch [ 1730/ 5000] | d_X_loss: 0.3603 | d_Y_loss: 0.3618 | g_total_loss: 2.4426
# Epoch [ 1740/ 5000] | d_X_loss: 0.4083 | d_Y_loss: 0.3150 | g_total_loss: 2.6832
# Epoch [ 1750/ 5000] | d_X_loss: 0.3800 | d_Y_loss: 0.3660 | g_total_loss: 2.3398
# Epoch [ 1760/ 5000] | d_X_loss: 0.3016 | d_Y_loss: 0.3344 | g_total_loss: 2.8564
# Epoch [ 1770/ 5000] | d_X_loss: 0.3812 | d_Y_loss: 0.3707 | g_total_loss: 2.4017
# Epoch [ 1780/ 5000] | d_X_loss: 0.4339 | d_Y_loss: 0.3227 | g_total_loss: 2.6209
# Epoch [ 1790/ 5000] | d_X_loss: 0.2970 | d_Y_loss: 0.3489 | g_total_loss: 2.6424
# Epoch [ 1800/ 5000] | d_X_loss: 0.3032 | d_Y_loss: 0.3371 | g_total_loss: 2.7993
# Epoch [ 1810/ 5000] | d_X_loss: 0.3056 | d_Y_loss: 0.3617 | g_total_loss: 2.6248
# Epoch [ 1820/ 5000] | d_X_loss: 0.4271 | d_Y_loss: 0.3134 | g_total_loss: 2.6683
# Epoch [ 1830/ 5000] | d_X_loss: 0.3162 | d_Y_loss: 0.3582 | g_total_loss: 2.5910
# Epoch [ 1840/ 5000] | d_X_loss: 0.4318 | d_Y_loss: 0.3146 | g_total_loss: 2.5864
# Epoch [ 1850/ 5000] | d_X_loss: 0.3212 | d_Y_loss: 0.3660 | g_total_loss: 2.5858
# Epoch [ 1860/ 5000] | d_X_loss: 0.4413 | d_Y_loss: 0.3145 | g_total_loss: 2.5672
# Epoch [ 1870/ 5000] | d_X_loss: 0.4240 | d_Y_loss: 0.3563 | g_total_loss: 2.2897
# Epoch [ 1880/ 5000] | d_X_loss: 0.3203 | d_Y_loss: 0.3426 | g_total_loss: 2.8128
# Epoch [ 1890/ 5000] | d_X_loss: 0.3457 | d_Y_loss: 0.3504 | g_total_loss: 2.5500
# Epoch [ 1900/ 5000] | d_X_loss: 0.3228 | d_Y_loss: 0.3373 | g_total_loss: 2.7509
# Epoch [ 1910/ 5000] | d_X_loss: 0.4271 | d_Y_loss: 0.3495 | g_total_loss: 2.2978
# Epoch [ 1920/ 5000] | d_X_loss: 0.4659 | d_Y_loss: 0.3111 | g_total_loss: 2.5391
# Epoch [ 1930/ 5000] | d_X_loss: 0.4278 | d_Y_loss: 0.3344 | g_total_loss: 2.2873
# Epoch [ 1940/ 5000] | d_X_loss: 0.4483 | d_Y_loss: 0.3071 | g_total_loss: 2.5550
# Epoch [ 1950/ 5000] | d_X_loss: 0.4403 | d_Y_loss: 0.3452 | g_total_loss: 2.2949
# Epoch [ 1960/ 5000] | d_X_loss: 0.3367 | d_Y_loss: 0.3412 | g_total_loss: 2.7397
# Epoch [ 1970/ 5000] | d_X_loss: 0.4326 | d_Y_loss: 0.3317 | g_total_loss: 2.2896
# Epoch [ 1980/ 5000] | d_X_loss: 0.3326 | d_Y_loss: 0.3456 | g_total_loss: 2.7111
# Epoch [ 1990/ 5000] | d_X_loss: 0.4179 | d_Y_loss: 0.3352 | g_total_loss: 2.2782
# Epoch [ 2000/ 5000] | d_X_loss: 0.4500 | d_Y_loss: 0.3058 | g_total_loss: 2.5290
# Epoch [ 2010/ 5000] | d_X_loss: 0.4140 | d_Y_loss: 0.3215 | g_total_loss: 2.3085
# Epoch [ 2020/ 5000] | d_X_loss: 0.4338 | d_Y_loss: 0.3012 | g_total_loss: 2.5746
# Epoch [ 2030/ 5000] | d_X_loss: 0.4085 | d_Y_loss: 0.3287 | g_total_loss: 2.2970
# Epoch [ 2040/ 5000] | d_X_loss: 0.3350 | d_Y_loss: 0.3494 | g_total_loss: 2.6989
# Epoch [ 2050/ 5000] | d_X_loss: 0.4082 | d_Y_loss: 0.3212 | g_total_loss: 2.2412
# Epoch [ 2060/ 5000] | d_X_loss: 0.4341 | d_Y_loss: 0.2973 | g_total_loss: 2.5559
# Epoch [ 2070/ 5000] | d_X_loss: 0.4039 | d_Y_loss: 0.3232 | g_total_loss: 2.2532
# Epoch [ 2080/ 5000] | d_X_loss: 0.3278 | d_Y_loss: 0.3448 | g_total_loss: 2.7074
# Epoch [ 2090/ 5000] | d_X_loss: 0.4173 | d_Y_loss: 0.3190 | g_total_loss: 2.2145
# Epoch [ 2100/ 5000] | d_X_loss: 0.4222 | d_Y_loss: 0.2970 | g_total_loss: 2.5275
# Epoch [ 2110/ 5000] | d_X_loss: 0.4030 | d_Y_loss: 0.3183 | g_total_loss: 2.2586
# Epoch [ 2120/ 5000] | d_X_loss: 0.4116 | d_Y_loss: 0.2944 | g_total_loss: 2.5779
# Epoch [ 2130/ 5000] | d_X_loss: 0.4005 | d_Y_loss: 0.3120 | g_total_loss: 2.2366
# Epoch [ 2140/ 5000] | d_X_loss: 0.3263 | d_Y_loss: 0.3507 | g_total_loss: 2.6622
# Epoch [ 2150/ 5000] | d_X_loss: 0.3951 | d_Y_loss: 0.3162 | g_total_loss: 2.2509
# Epoch [ 2160/ 5000] | d_X_loss: 0.3339 | d_Y_loss: 0.3534 | g_total_loss: 2.6634
# Epoch [ 2170/ 5000] | d_X_loss: 0.3881 | d_Y_loss: 0.3058 | g_total_loss: 2.2584
# Epoch [ 2180/ 5000] | d_X_loss: 0.3946 | d_Y_loss: 0.2921 | g_total_loss: 2.5457
# Epoch [ 2190/ 5000] | d_X_loss: 0.3866 | d_Y_loss: 0.3102 | g_total_loss: 2.2706
# Epoch [ 2200/ 5000] | d_X_loss: 0.3936 | d_Y_loss: 0.2894 | g_total_loss: 2.4906
# Epoch [ 2210/ 5000] | d_X_loss: 0.3823 | d_Y_loss: 0.3035 | g_total_loss: 2.2252
# Epoch [ 2220/ 5000] | d_X_loss: 0.3285 | d_Y_loss: 0.3581 | g_total_loss: 2.6460
# Epoch [ 2230/ 5000] | d_X_loss: 0.3307 | d_Y_loss: 0.3248 | g_total_loss: 2.4908
# Epoch [ 2240/ 5000] | d_X_loss: 0.3785 | d_Y_loss: 0.2847 | g_total_loss: 2.5547
# Epoch [ 2250/ 5000] | d_X_loss: 0.3821 | d_Y_loss: 0.3022 | g_total_loss: 2.2692
# Epoch [ 2260/ 5000] | d_X_loss: 0.3209 | d_Y_loss: 0.3539 | g_total_loss: 2.6609
# Epoch [ 2270/ 5000] | d_X_loss: 0.3274 | d_Y_loss: 0.3255 | g_total_loss: 2.4850
# Epoch [ 2280/ 5000] | d_X_loss: 0.3858 | d_Y_loss: 0.2827 | g_total_loss: 2.5049
# Epoch [ 2290/ 5000] | d_X_loss: 0.3766 | d_Y_loss: 0.2956 | g_total_loss: 2.2266
# Epoch [ 2300/ 5000] | d_X_loss: 0.3124 | d_Y_loss: 0.3611 | g_total_loss: 2.6241
# Epoch [ 2310/ 5000] | d_X_loss: 0.3778 | d_Y_loss: 0.3004 | g_total_loss: 2.2100
# Epoch [ 2320/ 5000] | d_X_loss: 0.3764 | d_Y_loss: 0.2815 | g_total_loss: 2.4877
# Epoch [ 2330/ 5000] | d_X_loss: 0.3751 | d_Y_loss: 0.2984 | g_total_loss: 2.2192
# Epoch [ 2340/ 5000] | d_X_loss: 0.3120 | d_Y_loss: 0.3655 | g_total_loss: 2.6305
# Epoch [ 2350/ 5000] | d_X_loss: 0.3774 | d_Y_loss: 0.3022 | g_total_loss: 2.2571
# Epoch [ 2360/ 5000] | d_X_loss: 0.3777 | d_Y_loss: 0.2776 | g_total_loss: 2.5062
# Epoch [ 2370/ 5000] | d_X_loss: 0.3321 | d_Y_loss: 0.3022 | g_total_loss: 2.4918
# Epoch [ 2380/ 5000] | d_X_loss: 0.3060 | d_Y_loss: 0.3698 | g_total_loss: 2.6439
# Epoch [ 2390/ 5000] | d_X_loss: 0.3652 | d_Y_loss: 0.2963 | g_total_loss: 2.2086
# Epoch [ 2400/ 5000] | d_X_loss: 0.3089 | d_Y_loss: 0.3662 | g_total_loss: 2.5858
# Epoch [ 2410/ 5000] | d_X_loss: 0.3646 | d_Y_loss: 0.2936 | g_total_loss: 2.2093
# Epoch [ 2420/ 5000] | d_X_loss: 0.3545 | d_Y_loss: 0.2749 | g_total_loss: 2.4777
# Epoch [ 2430/ 5000] | d_X_loss: 0.3188 | d_Y_loss: 0.3019 | g_total_loss: 2.4563
# Epoch [ 2440/ 5000] | d_X_loss: 0.3672 | d_Y_loss: 0.2757 | g_total_loss: 2.4620
# Epoch [ 2450/ 5000] | d_X_loss: 0.3278 | d_Y_loss: 0.2929 | g_total_loss: 2.4943
# Epoch [ 2460/ 5000] | d_X_loss: 0.3618 | d_Y_loss: 0.2730 | g_total_loss: 2.4980
# Epoch [ 2470/ 5000] | d_X_loss: 0.3164 | d_Y_loss: 0.2964 | g_total_loss: 2.4432
# Epoch [ 2480/ 5000] | d_X_loss: 0.3004 | d_Y_loss: 0.3705 | g_total_loss: 2.5684
# Epoch [ 2490/ 5000] | d_X_loss: 0.3212 | d_Y_loss: 0.2941 | g_total_loss: 2.4453
# Epoch [ 2500/ 5000] | d_X_loss: 0.3552 | d_Y_loss: 0.2712 | g_total_loss: 2.4754
# Epoch [ 2510/ 5000] | d_X_loss: 0.3616 | d_Y_loss: 0.2919 | g_total_loss: 2.1810
# Epoch [ 2520/ 5000] | d_X_loss: 0.2987 | d_Y_loss: 0.3711 | g_total_loss: 2.6034
# Epoch [ 2530/ 5000] | d_X_loss: 0.3613 | d_Y_loss: 0.2889 | g_total_loss: 2.1679
# Epoch [ 2540/ 5000] | d_X_loss: 0.3511 | d_Y_loss: 0.2714 | g_total_loss: 2.4877
# Epoch [ 2550/ 5000] | d_X_loss: 0.3630 | d_Y_loss: 0.2887 | g_total_loss: 2.2208
# Epoch [ 2560/ 5000] | d_X_loss: 0.2883 | d_Y_loss: 0.3684 | g_total_loss: 2.5962
# Epoch [ 2570/ 5000] | d_X_loss: 0.3529 | d_Y_loss: 0.2852 | g_total_loss: 2.1974
# Epoch [ 2580/ 5000] | d_X_loss: 0.2925 | d_Y_loss: 0.3704 | g_total_loss: 2.5979
# Epoch [ 2590/ 5000] | d_X_loss: 0.3167 | d_Y_loss: 0.2978 | g_total_loss: 2.4442
# Epoch [ 2600/ 5000] | d_X_loss: 0.2850 | d_Y_loss: 0.3713 | g_total_loss: 2.5723
# Epoch [ 2610/ 5000] | d_X_loss: 0.3480 | d_Y_loss: 0.2830 | g_total_loss: 2.1878
# Epoch [ 2620/ 5000] | d_X_loss: 0.3492 | d_Y_loss: 0.2671 | g_total_loss: 2.5083
# Epoch [ 2630/ 5000] | d_X_loss: 0.3475 | d_Y_loss: 0.2823 | g_total_loss: 2.2262
# Epoch [ 2640/ 5000] | d_X_loss: 0.2803 | d_Y_loss: 0.3697 | g_total_loss: 2.5911
# Epoch [ 2650/ 5000] | d_X_loss: 0.3444 | d_Y_loss: 0.2812 | g_total_loss: 2.1851
# Epoch [ 2660/ 5000] | d_X_loss: 0.2782 | d_Y_loss: 0.3658 | g_total_loss: 2.5716
# Epoch [ 2670/ 5000] | d_X_loss: 0.3428 | d_Y_loss: 0.2810 | g_total_loss: 2.2243
# Epoch [ 2680/ 5000] | d_X_loss: 0.3425 | d_Y_loss: 0.2631 | g_total_loss: 2.4889
# Epoch [ 2690/ 5000] | d_X_loss: 0.3104 | d_Y_loss: 0.2921 | g_total_loss: 2.4349
# Epoch [ 2700/ 5000] | d_X_loss: 0.3438 | d_Y_loss: 0.2613 | g_total_loss: 2.4589
# Epoch [ 2710/ 5000] | d_X_loss: 0.3376 | d_Y_loss: 0.2773 | g_total_loss: 2.1926
# Epoch [ 2720/ 5000] | d_X_loss: 0.3387 | d_Y_loss: 0.2604 | g_total_loss: 2.4454
# Epoch [ 2730/ 5000] | d_X_loss: 0.3476 | d_Y_loss: 0.2841 | g_total_loss: 2.1598
# Epoch [ 2740/ 5000] | d_X_loss: 0.3421 | d_Y_loss: 0.2615 | g_total_loss: 2.4286
# Epoch [ 2750/ 5000] | d_X_loss: 0.3360 | d_Y_loss: 0.2808 | g_total_loss: 2.1787
# Epoch [ 2760/ 5000] | d_X_loss: 0.3424 | d_Y_loss: 0.2592 | g_total_loss: 2.4304
# Epoch [ 2770/ 5000] | d_X_loss: 0.3369 | d_Y_loss: 0.2816 | g_total_loss: 2.1986
# Epoch [ 2780/ 5000] | d_X_loss: 0.3364 | d_Y_loss: 0.2605 | g_total_loss: 2.4314
# Epoch [ 2790/ 5000] | d_X_loss: 0.3353 | d_Y_loss: 0.2799 | g_total_loss: 2.1937
# Epoch [ 2800/ 5000] | d_X_loss: 0.3357 | d_Y_loss: 0.2568 | g_total_loss: 2.4889
# Epoch [ 2810/ 5000] | d_X_loss: 0.3363 | d_Y_loss: 0.2797 | g_total_loss: 2.1981
# Epoch [ 2820/ 5000] | d_X_loss: 0.2624 | d_Y_loss: 0.3778 | g_total_loss: 2.5447
# Epoch [ 2830/ 5000] | d_X_loss: 0.2904 | d_Y_loss: 0.2751 | g_total_loss: 2.4181
# Epoch [ 2840/ 5000] | d_X_loss: 0.3358 | d_Y_loss: 0.2571 | g_total_loss: 2.4197
# Epoch [ 2850/ 5000] | d_X_loss: 0.2919 | d_Y_loss: 0.2764 | g_total_loss: 2.3818
# Epoch [ 2860/ 5000] | d_X_loss: 0.3215 | d_Y_loss: 0.2560 | g_total_loss: 2.4581
# Epoch [ 2870/ 5000] | d_X_loss: 0.3281 | d_Y_loss: 0.2752 | g_total_loss: 2.2268
# Epoch [ 2880/ 5000] | d_X_loss: 0.3267 | d_Y_loss: 0.2567 | g_total_loss: 2.4761
# Epoch [ 2890/ 5000] | d_X_loss: 0.3264 | d_Y_loss: 0.2751 | g_total_loss: 2.1738
# Epoch [ 2900/ 5000] | d_X_loss: 0.2578 | d_Y_loss: 0.3796 | g_total_loss: 2.6100
# Epoch [ 2910/ 5000] | d_X_loss: 0.2939 | d_Y_loss: 0.2748 | g_total_loss: 2.4166
# Epoch [ 2920/ 5000] | d_X_loss: 0.2498 | d_Y_loss: 0.3708 | g_total_loss: 2.5398
# Epoch [ 2930/ 5000] | d_X_loss: 0.2882 | d_Y_loss: 0.2702 | g_total_loss: 2.3953
# Epoch [ 2940/ 5000] | d_X_loss: 0.2502 | d_Y_loss: 0.3765 | g_total_loss: 2.5366
# Epoch [ 2950/ 5000] | d_X_loss: 0.3171 | d_Y_loss: 0.2750 | g_total_loss: 2.1383
# Epoch [ 2960/ 5000] | d_X_loss: 0.2494 | d_Y_loss: 0.3776 | g_total_loss: 2.5549
# Epoch [ 2970/ 5000] | d_X_loss: 0.2828 | d_Y_loss: 0.2708 | g_total_loss: 2.4027
# Epoch [ 2980/ 5000] | d_X_loss: 0.3242 | d_Y_loss: 0.2546 | g_total_loss: 2.4133
# Epoch [ 2990/ 5000] | d_X_loss: 0.2825 | d_Y_loss: 0.2612 | g_total_loss: 2.3702
# Epoch [ 3000/ 5000] | d_X_loss: 0.3297 | d_Y_loss: 0.2521 | g_total_loss: 2.4381
# Epoch [ 3010/ 5000] | d_X_loss: 0.3125 | d_Y_loss: 0.2740 | g_total_loss: 2.1799
# Epoch [ 3020/ 5000] | d_X_loss: 0.3237 | d_Y_loss: 0.2535 | g_total_loss: 2.3953
# Epoch [ 3030/ 5000] | d_X_loss: 0.2772 | d_Y_loss: 0.2635 | g_total_loss: 2.3504
# Epoch [ 3040/ 5000] | d_X_loss: 0.3272 | d_Y_loss: 0.2514 | g_total_loss: 2.3730
# Epoch [ 3050/ 5000] | d_X_loss: 0.3013 | d_Y_loss: 0.2712 | g_total_loss: 2.2154
# Epoch [ 3060/ 5000] | d_X_loss: 0.2395 | d_Y_loss: 0.3807 | g_total_loss: 2.5516
# Epoch [ 3070/ 5000] | d_X_loss: 0.2751 | d_Y_loss: 0.2617 | g_total_loss: 2.3678
# Epoch [ 3080/ 5000] | d_X_loss: 0.3236 | d_Y_loss: 0.2518 | g_total_loss: 2.4143
# Epoch [ 3090/ 5000] | d_X_loss: 0.2764 | d_Y_loss: 0.2596 | g_total_loss: 2.4016
# Epoch [ 3100/ 5000] | d_X_loss: 0.2370 | d_Y_loss: 0.3783 | g_total_loss: 2.5481
# Epoch [ 3110/ 5000] | d_X_loss: 0.2991 | d_Y_loss: 0.2685 | g_total_loss: 2.1766
# Epoch [ 3120/ 5000] | d_X_loss: 0.2398 | d_Y_loss: 0.3769 | g_total_loss: 2.5426
# Epoch [ 3130/ 5000] | d_X_loss: 0.2911 | d_Y_loss: 0.2705 | g_total_loss: 2.1815
# Epoch [ 3140/ 5000] | d_X_loss: 0.3163 | d_Y_loss: 0.2494 | g_total_loss: 2.3725
# Epoch [ 3150/ 5000] | d_X_loss: 0.2778 | d_Y_loss: 0.2500 | g_total_loss: 2.3625
# Epoch [ 3160/ 5000] | d_X_loss: 0.3261 | d_Y_loss: 0.2498 | g_total_loss: 2.3820
# Epoch [ 3170/ 5000] | d_X_loss: 0.2942 | d_Y_loss: 0.2728 | g_total_loss: 2.1677
# Epoch [ 3180/ 5000] | d_X_loss: 0.3243 | d_Y_loss: 0.2495 | g_total_loss: 2.3849
# Epoch [ 3190/ 5000] | d_X_loss: 0.2680 | d_Y_loss: 0.2492 | g_total_loss: 2.3439
# Epoch [ 3200/ 5000] | d_X_loss: 0.2339 | d_Y_loss: 0.3686 | g_total_loss: 2.5005
# Epoch [ 3210/ 5000] | d_X_loss: 0.2922 | d_Y_loss: 0.2716 | g_total_loss: 2.1904
# Epoch [ 3220/ 5000] | d_X_loss: 0.3148 | d_Y_loss: 0.2486 | g_total_loss: 2.4093
# Epoch [ 3230/ 5000] | d_X_loss: 0.2701 | d_Y_loss: 0.2516 | g_total_loss: 2.3795
# Epoch [ 3240/ 5000] | d_X_loss: 0.2341 | d_Y_loss: 0.3732 | g_total_loss: 2.5559
# Epoch [ 3250/ 5000] | d_X_loss: 0.2854 | d_Y_loss: 0.2683 | g_total_loss: 2.1731
# Epoch [ 3260/ 5000] | d_X_loss: 0.3078 | d_Y_loss: 0.2464 | g_total_loss: 2.3857
# Epoch [ 3270/ 5000] | d_X_loss: 0.2811 | d_Y_loss: 0.2670 | g_total_loss: 2.1548
# Epoch [ 3280/ 5000] | d_X_loss: 0.3127 | d_Y_loss: 0.2445 | g_total_loss: 2.3403
# Epoch [ 3290/ 5000] | d_X_loss: 0.2775 | d_Y_loss: 0.2652 | g_total_loss: 2.1795
# Epoch [ 3300/ 5000] | d_X_loss: 0.2288 | d_Y_loss: 0.3698 | g_total_loss: 2.5135
# Epoch [ 3310/ 5000] | d_X_loss: 0.2635 | d_Y_loss: 0.2488 | g_total_loss: 2.3600
# Epoch [ 3320/ 5000] | d_X_loss: 0.2278 | d_Y_loss: 0.3662 | g_total_loss: 2.5161
# Epoch [ 3330/ 5000] | d_X_loss: 0.2769 | d_Y_loss: 0.2641 | g_total_loss: 2.1603
# Epoch [ 3340/ 5000] | d_X_loss: 0.3247 | d_Y_loss: 0.2444 | g_total_loss: 2.3402
# Epoch [ 3350/ 5000] | d_X_loss: 0.2799 | d_Y_loss: 0.2624 | g_total_loss: 2.1809
# Epoch [ 3360/ 5000] | d_X_loss: 0.3156 | d_Y_loss: 0.2433 | g_total_loss: 2.3689
# Epoch [ 3370/ 5000] | d_X_loss: 0.2602 | d_Y_loss: 0.2474 | g_total_loss: 2.3336
# Epoch [ 3380/ 5000] | d_X_loss: 0.3106 | d_Y_loss: 0.2436 | g_total_loss: 2.3700
# Epoch [ 3390/ 5000] | d_X_loss: 0.2754 | d_Y_loss: 0.2602 | g_total_loss: 2.1986
# Epoch [ 3400/ 5000] | d_X_loss: 0.3019 | d_Y_loss: 0.2411 | g_total_loss: 2.4045
# Epoch [ 3410/ 5000] | d_X_loss: 0.2625 | d_Y_loss: 0.2468 | g_total_loss: 2.3661
# Epoch [ 3420/ 5000] | d_X_loss: 0.2289 | d_Y_loss: 0.3647 | g_total_loss: 2.4810
# Epoch [ 3430/ 5000] | d_X_loss: 0.2704 | d_Y_loss: 0.2616 | g_total_loss: 2.1639
# Epoch [ 3440/ 5000] | d_X_loss: 0.3085 | d_Y_loss: 0.2394 | g_total_loss: 2.3415
# Epoch [ 3450/ 5000] | d_X_loss: 0.2739 | d_Y_loss: 0.2590 | g_total_loss: 2.1777
# Epoch [ 3460/ 5000] | d_X_loss: 0.2288 | d_Y_loss: 0.3714 | g_total_loss: 2.5105
# Epoch [ 3470/ 5000] | d_X_loss: 0.2706 | d_Y_loss: 0.2595 | g_total_loss: 2.1536
# Epoch [ 3480/ 5000] | d_X_loss: 0.2285 | d_Y_loss: 0.3573 | g_total_loss: 2.4862
# Epoch [ 3490/ 5000] | d_X_loss: 0.2695 | d_Y_loss: 0.2592 | g_total_loss: 2.1659
# Epoch [ 3500/ 5000] | d_X_loss: 0.2271 | d_Y_loss: 0.3635 | g_total_loss: 2.4789
# Epoch [ 3510/ 5000] | d_X_loss: 0.2563 | d_Y_loss: 0.2487 | g_total_loss: 2.3321
# Epoch [ 3520/ 5000] | d_X_loss: 0.2294 | d_Y_loss: 0.3663 | g_total_loss: 2.5045
# Epoch [ 3530/ 5000] | d_X_loss: 0.2707 | d_Y_loss: 0.2599 | g_total_loss: 2.1414
# Epoch [ 3540/ 5000] | d_X_loss: 0.3089 | d_Y_loss: 0.2409 | g_total_loss: 2.3579
# Epoch [ 3550/ 5000] | d_X_loss: 0.2523 | d_Y_loss: 0.2451 | g_total_loss: 2.3174
# Epoch [ 3560/ 5000] | d_X_loss: 0.2311 | d_Y_loss: 0.3588 | g_total_loss: 2.4760
# Epoch [ 3570/ 5000] | d_X_loss: 0.2663 | d_Y_loss: 0.2571 | g_total_loss: 2.1629
# Epoch [ 3580/ 5000] | d_X_loss: 0.2261 | d_Y_loss: 0.3568 | g_total_loss: 2.4849
# Epoch [ 3590/ 5000] | d_X_loss: 0.2682 | d_Y_loss: 0.2560 | g_total_loss: 2.1570
# Epoch [ 3600/ 5000] | d_X_loss: 0.3057 | d_Y_loss: 0.2399 | g_total_loss: 2.3423
# Epoch [ 3610/ 5000] | d_X_loss: 0.2537 | d_Y_loss: 0.2379 | g_total_loss: 2.3340
# Epoch [ 3620/ 5000] | d_X_loss: 0.3088 | d_Y_loss: 0.2372 | g_total_loss: 2.3564
# Epoch [ 3630/ 5000] | d_X_loss: 0.2646 | d_Y_loss: 0.2549 | g_total_loss: 2.1662
# Epoch [ 3640/ 5000] | d_X_loss: 0.3096 | d_Y_loss: 0.2371 | g_total_loss: 2.3168
# Epoch [ 3650/ 5000] | d_X_loss: 0.2643 | d_Y_loss: 0.2546 | g_total_loss: 2.1553
# Epoch [ 3660/ 5000] | d_X_loss: 0.3095 | d_Y_loss: 0.2366 | g_total_loss: 2.3492
# Epoch [ 3670/ 5000] | d_X_loss: 0.2609 | d_Y_loss: 0.2530 | g_total_loss: 2.1962
# Epoch [ 3680/ 5000] | d_X_loss: 0.3006 | d_Y_loss: 0.2362 | g_total_loss: 2.3503
# Epoch [ 3690/ 5000] | d_X_loss: 0.2641 | d_Y_loss: 0.2503 | g_total_loss: 2.1813
# Epoch [ 3700/ 5000] | d_X_loss: 0.3029 | d_Y_loss: 0.2351 | g_total_loss: 2.3541
# Epoch [ 3710/ 5000] | d_X_loss: 0.2482 | d_Y_loss: 0.2448 | g_total_loss: 2.3335
# Epoch [ 3720/ 5000] | d_X_loss: 0.3024 | d_Y_loss: 0.2338 | g_total_loss: 2.3320
# Epoch [ 3730/ 5000] | d_X_loss: 0.2641 | d_Y_loss: 0.2506 | g_total_loss: 2.1949
# Epoch [ 3740/ 5000] | d_X_loss: 0.3011 | d_Y_loss: 0.2353 | g_total_loss: 2.3583
# Epoch [ 3750/ 5000] | d_X_loss: 0.2574 | d_Y_loss: 0.2507 | g_total_loss: 2.1741
# Epoch [ 3760/ 5000] | d_X_loss: 0.2965 | d_Y_loss: 0.2331 | g_total_loss: 2.3610
# Epoch [ 3770/ 5000] | d_X_loss: 0.2601 | d_Y_loss: 0.2495 | g_total_loss: 2.1296
# Epoch [ 3780/ 5000] | d_X_loss: 0.2994 | d_Y_loss: 0.2339 | g_total_loss: 2.3407
# Epoch [ 3790/ 5000] | d_X_loss: 0.2572 | d_Y_loss: 0.2491 | g_total_loss: 2.1583
# Epoch [ 3800/ 5000] | d_X_loss: 0.2330 | d_Y_loss: 0.3648 | g_total_loss: 2.4717
# Epoch [ 3810/ 5000] | d_X_loss: 0.2595 | d_Y_loss: 0.2476 | g_total_loss: 2.1508
# Epoch [ 3820/ 5000] | d_X_loss: 0.2324 | d_Y_loss: 0.3626 | g_total_loss: 2.4565
# Epoch [ 3830/ 5000] | d_X_loss: 0.2452 | d_Y_loss: 0.2356 | g_total_loss: 2.3370
# Epoch [ 3840/ 5000] | d_X_loss: 0.2324 | d_Y_loss: 0.3659 | g_total_loss: 2.4689
# Epoch [ 3850/ 5000] | d_X_loss: 0.2597 | d_Y_loss: 0.2495 | g_total_loss: 2.1560
# Epoch [ 3860/ 5000] | d_X_loss: 0.2982 | d_Y_loss: 0.2321 | g_total_loss: 2.3490
# Epoch [ 3870/ 5000] | d_X_loss: 0.2464 | d_Y_loss: 0.2360 | g_total_loss: 2.3090
# Epoch [ 3880/ 5000] | d_X_loss: 0.2320 | d_Y_loss: 0.3666 | g_total_loss: 2.4676
# Epoch [ 3890/ 5000] | d_X_loss: 0.2550 | d_Y_loss: 0.2496 | g_total_loss: 2.1339
# Epoch [ 3900/ 5000] | d_X_loss: 0.2993 | d_Y_loss: 0.2326 | g_total_loss: 2.3356
# Epoch [ 3910/ 5000] | d_X_loss: 0.2565 | d_Y_loss: 0.2494 | g_total_loss: 2.1417
# Epoch [ 3920/ 5000] | d_X_loss: 0.2987 | d_Y_loss: 0.2303 | g_total_loss: 2.3123
# Epoch [ 3930/ 5000] | d_X_loss: 0.2557 | d_Y_loss: 0.2498 | g_total_loss: 2.1326
# Epoch [ 3940/ 5000] | d_X_loss: 0.2301 | d_Y_loss: 0.3528 | g_total_loss: 2.4242
# Epoch [ 3950/ 5000] | d_X_loss: 0.2555 | d_Y_loss: 0.2491 | g_total_loss: 2.1153
# Epoch [ 3960/ 5000] | d_X_loss: 0.2992 | d_Y_loss: 0.2318 | g_total_loss: 2.3138
# Epoch [ 3970/ 5000] | d_X_loss: 0.2445 | d_Y_loss: 0.2317 | g_total_loss: 2.2936
# Epoch [ 3980/ 5000] | d_X_loss: 0.3024 | d_Y_loss: 0.2326 | g_total_loss: 2.3493
# Epoch [ 3990/ 5000] | d_X_loss: 0.2533 | d_Y_loss: 0.2487 | g_total_loss: 2.1320
# Epoch [ 4000/ 5000] | d_X_loss: 0.2275 | d_Y_loss: 0.3508 | g_total_loss: 2.4171
# Epoch [ 4010/ 5000] | d_X_loss: 0.2439 | d_Y_loss: 0.2319 | g_total_loss: 2.2805
# Epoch [ 4020/ 5000] | d_X_loss: 0.3059 | d_Y_loss: 0.2332 | g_total_loss: 2.3009
# Epoch [ 4030/ 5000] | d_X_loss: 0.2527 | d_Y_loss: 0.2493 | g_total_loss: 2.1533
# Epoch [ 4040/ 5000] | d_X_loss: 0.3024 | d_Y_loss: 0.2325 | g_total_loss: 2.3080
# Epoch [ 4050/ 5000] | d_X_loss: 0.2542 | d_Y_loss: 0.2474 | g_total_loss: 2.1495
# Epoch [ 4060/ 5000] | d_X_loss: 0.2954 | d_Y_loss: 0.2332 | g_total_loss: 2.3226
# Epoch [ 4070/ 5000] | d_X_loss: 0.2479 | d_Y_loss: 0.2265 | g_total_loss: 2.3179
# Epoch [ 4080/ 5000] | d_X_loss: 0.2928 | d_Y_loss: 0.2322 | g_total_loss: 2.3323
# Epoch [ 4090/ 5000] | d_X_loss: 0.2472 | d_Y_loss: 0.2272 | g_total_loss: 2.3090
# Epoch [ 4100/ 5000] | d_X_loss: 0.2262 | d_Y_loss: 0.3639 | g_total_loss: 2.4495
# Epoch [ 4110/ 5000] | d_X_loss: 0.2545 | d_Y_loss: 0.2488 | g_total_loss: 2.1520
# Epoch [ 4120/ 5000] | d_X_loss: 0.2981 | d_Y_loss: 0.2316 | g_total_loss: 2.3229
# Epoch [ 4130/ 5000] | d_X_loss: 0.2485 | d_Y_loss: 0.2227 | g_total_loss: 2.3028
# Epoch [ 4140/ 5000] | d_X_loss: 0.2965 | d_Y_loss: 0.2311 | g_total_loss: 2.3087
# Epoch [ 4150/ 5000] | d_X_loss: 0.2505 | d_Y_loss: 0.2187 | g_total_loss: 2.3118
# Epoch [ 4160/ 5000] | d_X_loss: 0.2239 | d_Y_loss: 0.3612 | g_total_loss: 2.4334
# Epoch [ 4170/ 5000] | d_X_loss: 0.2519 | d_Y_loss: 0.2510 | g_total_loss: 2.1392
# Epoch [ 4180/ 5000] | d_X_loss: 0.2957 | d_Y_loss: 0.2301 | g_total_loss: 2.3091
# Epoch [ 4190/ 5000] | d_X_loss: 0.2483 | d_Y_loss: 0.2225 | g_total_loss: 2.2824
# Epoch [ 4200/ 5000] | d_X_loss: 0.2950 | d_Y_loss: 0.2312 | g_total_loss: 2.3069
# Epoch [ 4210/ 5000] | d_X_loss: 0.2514 | d_Y_loss: 0.2507 | g_total_loss: 2.1473
# Epoch [ 4220/ 5000] | d_X_loss: 0.2244 | d_Y_loss: 0.3635 | g_total_loss: 2.4424
# Epoch [ 4230/ 5000] | d_X_loss: 0.2504 | d_Y_loss: 0.2222 | g_total_loss: 2.2810
# Epoch [ 4240/ 5000] | d_X_loss: 0.2250 | d_Y_loss: 0.3607 | g_total_loss: 2.4293
# Epoch [ 4250/ 5000] | d_X_loss: 0.2538 | d_Y_loss: 0.2502 | g_total_loss: 2.1419
# Epoch [ 4260/ 5000] | d_X_loss: 0.2968 | d_Y_loss: 0.2312 | g_total_loss: 2.2964
# Epoch [ 4270/ 5000] | d_X_loss: 0.2515 | d_Y_loss: 0.2503 | g_total_loss: 2.1502
# Epoch [ 4280/ 5000] | d_X_loss: 0.2939 | d_Y_loss: 0.2307 | g_total_loss: 2.3179
# Epoch [ 4290/ 5000] | d_X_loss: 0.2526 | d_Y_loss: 0.2494 | g_total_loss: 2.1350
# Epoch [ 4300/ 5000] | d_X_loss: 0.2260 | d_Y_loss: 0.3605 | g_total_loss: 2.4203
# Epoch [ 4310/ 5000] | d_X_loss: 0.2528 | d_Y_loss: 0.2487 | g_total_loss: 2.1302
# Epoch [ 4320/ 5000] | d_X_loss: 0.2935 | d_Y_loss: 0.2311 | g_total_loss: 2.2994
# Epoch [ 4330/ 5000] | d_X_loss: 0.2528 | d_Y_loss: 0.2486 | g_total_loss: 2.1419
# Epoch [ 4340/ 5000] | d_X_loss: 0.2925 | d_Y_loss: 0.2310 | g_total_loss: 2.3060
# Epoch [ 4350/ 5000] | d_X_loss: 0.2533 | d_Y_loss: 0.2265 | g_total_loss: 2.2861
# Epoch [ 4360/ 5000] | d_X_loss: 0.2259 | d_Y_loss: 0.3663 | g_total_loss: 2.4435
# Epoch [ 4370/ 5000] | d_X_loss: 0.2527 | d_Y_loss: 0.2271 | g_total_loss: 2.2629
# Epoch [ 4380/ 5000] | d_X_loss: 0.2246 | d_Y_loss: 0.3647 | g_total_loss: 2.4320
# Epoch [ 4390/ 5000] | d_X_loss: 0.2531 | d_Y_loss: 0.2488 | g_total_loss: 2.1250
# Epoch [ 4400/ 5000] | d_X_loss: 0.2944 | d_Y_loss: 0.2308 | g_total_loss: 2.2839
# Epoch [ 4410/ 5000] | d_X_loss: 0.2543 | d_Y_loss: 0.2271 | g_total_loss: 2.2817
# Epoch [ 4420/ 5000] | d_X_loss: 0.2932 | d_Y_loss: 0.2319 | g_total_loss: 2.3020
# Epoch [ 4430/ 5000] | d_X_loss: 0.2551 | d_Y_loss: 0.2498 | g_total_loss: 2.1439
# Epoch [ 4440/ 5000] | d_X_loss: 0.2910 | d_Y_loss: 0.2318 | g_total_loss: 2.3073
# Epoch [ 4450/ 5000] | d_X_loss: 0.2550 | d_Y_loss: 0.2246 | g_total_loss: 2.2839
# Epoch [ 4460/ 5000] | d_X_loss: 0.2916 | d_Y_loss: 0.2311 | g_total_loss: 2.2898
# Epoch [ 4470/ 5000] | d_X_loss: 0.2536 | d_Y_loss: 0.2505 | g_total_loss: 2.1431
# Epoch [ 4480/ 5000] | d_X_loss: 0.2918 | d_Y_loss: 0.2311 | g_total_loss: 2.2934
# Epoch [ 4490/ 5000] | d_X_loss: 0.2561 | d_Y_loss: 0.2267 | g_total_loss: 2.2740
# Epoch [ 4500/ 5000] | d_X_loss: 0.2252 | d_Y_loss: 0.3668 | g_total_loss: 2.4249
# Epoch [ 4510/ 5000] | d_X_loss: 0.2541 | d_Y_loss: 0.2498 | g_total_loss: 2.1159
# Epoch [ 4520/ 5000] | d_X_loss: 0.2242 | d_Y_loss: 0.3625 | g_total_loss: 2.4065
# Epoch [ 4530/ 5000] | d_X_loss: 0.2554 | d_Y_loss: 0.2281 | g_total_loss: 2.2652
# Epoch [ 4540/ 5000] | d_X_loss: 0.2943 | d_Y_loss: 0.2318 | g_total_loss: 2.2697
# Epoch [ 4550/ 5000] | d_X_loss: 0.2537 | d_Y_loss: 0.2508 | g_total_loss: 2.1079
# Epoch [ 4560/ 5000] | d_X_loss: 0.2939 | d_Y_loss: 0.2321 | g_total_loss: 2.2757
# Epoch [ 4570/ 5000] | d_X_loss: 0.2548 | d_Y_loss: 0.2504 | g_total_loss: 2.1223
# Epoch [ 4580/ 5000] | d_X_loss: 0.2926 | d_Y_loss: 0.2323 | g_total_loss: 2.2849
# Epoch [ 4590/ 5000] | d_X_loss: 0.2552 | d_Y_loss: 0.2502 | g_total_loss: 2.1312
# Epoch [ 4600/ 5000] | d_X_loss: 0.2258 | d_Y_loss: 0.3675 | g_total_loss: 2.4223
# Epoch [ 4610/ 5000] | d_X_loss: 0.2559 | d_Y_loss: 0.2317 | g_total_loss: 2.2573
# Epoch [ 4620/ 5000] | d_X_loss: 0.2931 | d_Y_loss: 0.2326 | g_total_loss: 2.2696
# Epoch [ 4630/ 5000] | d_X_loss: 0.2553 | d_Y_loss: 0.2508 | g_total_loss: 2.1243
# Epoch [ 4640/ 5000] | d_X_loss: 0.2928 | d_Y_loss: 0.2328 | g_total_loss: 2.2698
# Epoch [ 4650/ 5000] | d_X_loss: 0.2557 | d_Y_loss: 0.2507 | g_total_loss: 2.1206
# Epoch [ 4660/ 5000] | d_X_loss: 0.2261 | d_Y_loss: 0.3683 | g_total_loss: 2.4195
# Epoch [ 4670/ 5000] | d_X_loss: 0.2571 | d_Y_loss: 0.2308 | g_total_loss: 2.2620
# Epoch [ 4680/ 5000] | d_X_loss: 0.2247 | d_Y_loss: 0.3642 | g_total_loss: 2.4019
# Epoch [ 4690/ 5000] | d_X_loss: 0.2556 | d_Y_loss: 0.2511 | g_total_loss: 2.1063
# Epoch [ 4700/ 5000] | d_X_loss: 0.2246 | d_Y_loss: 0.3662 | g_total_loss: 2.4127
# Epoch [ 4710/ 5000] | d_X_loss: 0.2561 | d_Y_loss: 0.2512 | g_total_loss: 2.1126
# Epoch [ 4720/ 5000] | d_X_loss: 0.2937 | d_Y_loss: 0.2338 | g_total_loss: 2.2675
# Epoch [ 4730/ 5000] | d_X_loss: 0.2564 | d_Y_loss: 0.2513 | g_total_loss: 2.1117
# Epoch [ 4740/ 5000] | d_X_loss: 0.2934 | d_Y_loss: 0.2341 | g_total_loss: 2.2719
# Epoch [ 4750/ 5000] | d_X_loss: 0.2588 | d_Y_loss: 0.2315 | g_total_loss: 2.2751
# Epoch [ 4760/ 5000] | d_X_loss: 0.2934 | d_Y_loss: 0.2344 | g_total_loss: 2.2712
# Epoch [ 4770/ 5000] | d_X_loss: 0.2586 | d_Y_loss: 0.2306 | g_total_loss: 2.2714
# Epoch [ 4780/ 5000] | d_X_loss: 0.2939 | d_Y_loss: 0.2345 | g_total_loss: 2.2703
# Epoch [ 4790/ 5000] | d_X_loss: 0.2568 | d_Y_loss: 0.2532 | g_total_loss: 2.1268
# Epoch [ 4800/ 5000] | d_X_loss: 0.2936 | d_Y_loss: 0.2347 | g_total_loss: 2.2751
# Epoch [ 4810/ 5000] | d_X_loss: 0.2597 | d_Y_loss: 0.2307 | g_total_loss: 2.2758
# Epoch [ 4820/ 5000] | d_X_loss: 0.2930 | d_Y_loss: 0.2348 | g_total_loss: 2.2783
# Epoch [ 4830/ 5000] | d_X_loss: 0.2569 | d_Y_loss: 0.2535 | g_total_loss: 2.1253
# Epoch [ 4840/ 5000] | d_X_loss: 0.2934 | d_Y_loss: 0.2348 | g_total_loss: 2.2746
# Epoch [ 4850/ 5000] | d_X_loss: 0.2597 | d_Y_loss: 0.2314 | g_total_loss: 2.2672
# Epoch [ 4860/ 5000] | d_X_loss: 0.2932 | d_Y_loss: 0.2347 | g_total_loss: 2.2697
# Epoch [ 4870/ 5000] | d_X_loss: 0.2567 | d_Y_loss: 0.2538 | g_total_loss: 2.1221
# Epoch [ 4880/ 5000] | d_X_loss: 0.2263 | d_Y_loss: 0.3720 | g_total_loss: 2.4206
# Epoch [ 4890/ 5000] | d_X_loss: 0.2564 | d_Y_loss: 0.2542 | g_total_loss: 2.1164
# Epoch [ 4900/ 5000] | d_X_loss: 0.2257 | d_Y_loss: 0.3711 | g_total_loss: 2.4159
# Epoch [ 4910/ 5000] | d_X_loss: 0.2566 | d_Y_loss: 0.2543 | g_total_loss: 2.1157
# Epoch [ 4920/ 5000] | d_X_loss: 0.2948 | d_Y_loss: 0.2350 | g_total_loss: 2.2592
# Epoch [ 4930/ 5000] | d_X_loss: 0.2590 | d_Y_loss: 0.2310 | g_total_loss: 2.2526
# Epoch [ 4940/ 5000] | d_X_loss: 0.2258 | d_Y_loss: 0.3698 | g_total_loss: 2.4104
# Epoch [ 4950/ 5000] | d_X_loss: 0.2568 | d_Y_loss: 0.2544 | g_total_loss: 2.1097
# Epoch [ 4960/ 5000] | d_X_loss: 0.2259 | d_Y_loss: 0.3692 | g_total_loss: 2.4080
# Epoch [ 4970/ 5000] | d_X_loss: 0.2568 | d_Y_loss: 0.2545 | g_total_loss: 2.1107
# Epoch [ 4980/ 5000] | d_X_loss: 0.2257 | d_Y_loss: 0.3693 | g_total_loss: 2.4097
# Epoch [ 4990/ 5000] | d_X_loss: 0.2592 | d_Y_loss: 0.2311 | g_total_loss: 2.2537
# Epoch [ 5000/ 5000] | d_X_loss: 0.2257 | d_Y_loss: 0.3691 | g_total_loss: 2.4091

# %%
#@markdown ### Training losses
fig, ax = plt.subplots(figsize=(12,8))
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator, RGB', alpha=0.5)
plt.plot(losses.T[1], label='Discriminator, Depth', alpha=0.5)
plt.plot(losses.T[2], label='Generators', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %%
def calculate_psnr():
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    
    images = iter(D)
    
    psnrs = []
    for i in range(64):
        images_RGB, images_Depth = next(images)
        images_RGB, images_Depth = scale(images_RGB), scale(images_Depth)

        images_RGB = images_RGB.to(device)
        images_Depth = images_Depth.to(device)

        fake_Depth = gen_A2B(images_RGB)
        fake_Depth = fake_Depth.detach().cpu().numpy()
        images_RGB = images_RGB.cpu().numpy()
        images_Depth = images_Depth.cpu().numpy()
    
        psnr = cv2.PSNR(images_Depth, fake_Depth)
        psnrs.append(psnr)
    return np.mean(psnrs)

# %%
print("PSNR of 64 samples:", calculate_psnr())
# Out:
# PSNR of 64 samples: 58.35583081655684
